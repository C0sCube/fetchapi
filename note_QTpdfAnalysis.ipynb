# %%
import fitz
import re, os
from pathlib import Path
import random
import time
from collections import Counter
from io import StringIO
import pandas as pd
import numpy as np
from scipy.signal import find_peaks

NUM_LINE_RE = re.compile(
    r"^\s*[\(\[\{]?\s*[₹$€£]?\s*[-+]?"
    r"\d[\d,]*(?:\.\d+)?%?"
    r"\s*[\)\]\}]?\s*$"
)
SECTION_RE = re.compile(r"\b(?:financial\s+statements|standalone|consolidated|balance\s+sheet|profit\s+(?:&|and)\s+loss|cash\s+flow)\b",re.I)
HEADLINE_RE = re.compile(r"\b(?:Standalone(?:\s+\S+){0,4}|Consolidated(?:\s+\S+){0,4})?\s+(?:Balance\s+Sheet|Profit\s+(?:and|&)\s+Loss|Cash\s+Flows?|Changes\s+In\s+Equity)\b", re.I)

# %%
def add_sequential_features(df, pdf_col="pdf", page_col="page_n", side_col="side"):
    df = df.copy()

    sort_cols = [pdf_col, page_col]
    if side_col in df.columns:
        sort_cols.append(side_col)
    df = df.sort_values(sort_cols).reset_index(drop=True)


    for c in [
        "rolling_median", "rolling_std", "robust_zscore",
        "run_length", "peak_prominence", "valley_prominence",
        "adjacent_page_similarity"
    ]:
        df[c] = np.nan

    df["high_activity"] = False
    df["peak_flag"] = False
    df["valley_flag"] = False

    for _, g in df.groupby(pdf_col):
        idx = g.index
        s = g["structural_score"]

        median = s.rolling(10, center=True, min_periods=1).median()
        std = s.rolling(10, center=True, min_periods=2).std().fillna(0)

        mad = s.rolling(10, center=True, min_periods=3).apply(
            lambda x: np.median(np.abs(x - np.median(x))), raw=True
        ).replace(0, np.nan)

        z = (
            0.6745 * (s - median) / mad
        ).replace([np.inf, -np.inf], np.nan).fillna(0)

        high = s >= median

        run = []
        current = 0
        for x in high:
            current = current + 1 if x else 0
            run.append(current)

        smooth = s.rolling(7, center=True, min_periods=1).median().to_numpy()

        peaks, pp = find_peaks(smooth, prominence=0.03, distance=2)
        valleys, vp = find_peaks(-smooth, prominence=0.03, distance=2)

        peak_prom = np.zeros(len(g))
        valley_prom = np.zeros(len(g))
        peak_flag = np.zeros(len(g), dtype=bool)
        valley_flag = np.zeros(len(g), dtype=bool)

        peak_prom[peaks] = pp["prominences"]
        valley_prom[valleys] = vp["prominences"]
        peak_flag[peaks] = True
        valley_flag[valleys] = True

        similarity = (1 - s.diff().abs()).clip(0, 1)

        df.loc[idx, "rolling_median"] = median.to_numpy()
        df.loc[idx, "rolling_std"] = np.round(std.to_numpy(),2)
        df.loc[idx, "robust_zscore"] = np.round(z.to_numpy(),2)
        df.loc[idx, "high_activity"] = high.to_numpy()
        df.loc[idx, "run_length"] = run
        df.loc[idx, "peak_prominence"] = peak_prom
        df.loc[idx, "peak_flag"] = peak_flag
        df.loc[idx, "valley_prominence"] = valley_prom
        df.loc[idx, "valley_flag"] = valley_flag
        df.loc[idx, "adjacent_page_similarity"] = similarity.to_numpy()

    return df

def gen_prb(st,et, n_lines=25):
    rng = random.Random(42) #seed
    lines = sorted(
        rng.uniform(st,et)
        for _ in range(n_lines)
    )
    return lines

def page_layout_metadata(page, ref_width, ref_height):
    w = page.rect.width
    h = page.rect.height

    spread = (w / ref_width) > 1.6 and (h / ref_height) > 0.7

    return {
        "width": int(w),
        "height": int(h),
        # "area": round(w * h, 2),
        # "rotation": page.rotation,
        "spread": spread,
        "split_x": round(w * 0.5, 2) if spread else None,
    }

def page_content_metadata_v1(page, layout, region):

    # margin_x = (region["x1"] - region["x0"]) * 0.05
    margin_y = (region["y1"] - region["y0"]) * 0.15

    left = region["x0"]
    right = region["x1"]
    top = region["y0"]
    bottom = region["y1"] - margin_y
    
    headline_bottom = (region["y0"] + (region["y1"] - region["y0"])*0.35 )

    numeric_data = []
    headline_text = []
    dirs = Counter()

    # char_count = 0
    line_count = 0
    block_count = 0
    blocks = page.get_text("dict")["blocks"]

    for block in blocks:
        if block["type"] != 0:
            continue
        
        block_count += 1
        
        for line in block["lines"]:

            x0, y0, x1, y1 = line["bbox"]

            # region restriction
            if  x1 < left or y1 < top or x0 > right or y0 > bottom:
                continue
            
            line_count += 1
            spans = line["spans"]
            dirs[tuple(map(round, line["dir"]))] += 1
            text = "".join(span["text"] for span in spans).strip()

            if not text:
                continue
            # char_count += len(text)
            
            # filter the 35% dude
            if y0 <= headline_bottom:
                headline_text.append(text)
            
            
            if NUM_LINE_RE.match(text):
                numeric_data.append(
                    {
                        "text": text,
                        "bbox": (x0, y0, x1, y1),
                        #imp
                        "cx": (x0 + x1) / 2,
                    }
       
                )

            # matches = SECTION_RE.findall(text)
            # if matches:
            #     segment_lines.extend(matches)

    if dirs:

        dominant = dirs.most_common(1)[0][0]

        text_dir = {
            (1, 0): "n",
            (0, -1): "90_cc",
            (0, 1): "90_c",
            (-1, 0): "ud",
        }.get(dominant, "n")

    else:
        text_dir = None

    numeric_count = len(numeric_data)
    headline_text = re.sub(r"\s+", " ", re.sub(r"[^A-Za-z0-9&\s]+", "", " ".join(headline_text))).strip()
    headline_matches = HEADLINE_RE.findall(headline_text)
    
    return {
        **layout,
        # "char_count": char_count,
        "line_count": line_count,
        "block_count": block_count,
        "t_dir": text_dir,
        "numeric_lines": numeric_data,
        "numeric_count": numeric_count,
        # "segment_lines": segment_lines,
        # "segment_count": len(segment_lines),
        "headline_data":headline_text,
        "head_match": headline_matches,
        "head_bool": bool(headline_matches),
        "probe_x": None if not numeric_count else gen_prb(region["x0"], region["x1"]),
        "probe_y": None if not numeric_count else gen_prb(region["y0"], region["y1"])
    }

def page_probe_metadata_v1(metadata):

    probes = metadata["probe_x"]
    yprobes = metadata["probe_y"]
    
    # print(f"X_PROBE: {probes} || Y_PROBE: {yprobes}")
    
    if not probes:
        metadata.update({
            "probe_x_hits":[],
            "probe_y_hits":[],
            # "max_hits":0,
            # "total_hits":0,
            # "hits_1":0,
            # "const_hit":0
        })
        
        return metadata
    
    xhits = [0] * len(probes)
    yhits = [0] * len(probes)
    # For X
    for item in metadata["numeric_lines"]:
        x0, _, x1, _ = item["bbox"]
        for i, px in enumerate(probes):
            if x0 <= px <= x1:
                xhits[i] += 1
    # For Y       
    for item in metadata["numeric_lines"]:
        _, y0, _, y1 = item["bbox"]
        for i, px in enumerate(yprobes):
            if y0 <= px <= y1:
                yhits[i] += 1

    metadata["probe_x_hits"] = xhits
    metadata["probe_y_hits"] = yhits
    # metadata["max_hits"] = max(hits)
    # metadata["total_hits"] = sum(hits)
    # metadata["hits_1"] = sum(h > 1 for h in hits)
    # metadata["cons_hit"] = consecutive_hits(hits, threshold=1)
    
    return metadata

def consecutive_hits(hits, threshold=0):
    longest = 0
    current = 0
    for h in hits:
        if h > threshold:
            current += 1
            longest = max(longest, current)
        else:
            current = 0
    return longest

def page_text_or_scanned(page):

    text = page.get_text("text").strip()
    page_rect = page.rect
    page_area = page_rect.width * page_rect.height

    if page_area <= 0:
        return "scanned"

    image_area = 0
    for img in page.get_images(full=True):
        try:
            xref = img[0]
            for rect in page.get_image_rects(xref):
                clipped = rect & page_rect
                if clipped.is_empty:
                    continue

                rect_area = clipped.width * clipped.height
                # Ignore small logos
                if rect_area > page_area * 0.05:
                    image_area += rect_area

        except Exception:
            continue

    image_coverage = min(image_area / page_area, 1.0)
    blocks = page.get_text("blocks")
    text_blocks = [
        block for block in blocks if len(block) >= 5 and str(block[4]).strip()
    ]

    num_text_blocks = len(text_blocks)

    # Strong text page
    if len(text) > 100 and num_text_blocks >= 3 and image_coverage < 0.8:
        return "text"
    # Strong scanned page
    if image_coverage > 0.8 and len(text) < 100:
        return "scanned"
    # OCR scanned page
    if image_coverage > 0.9 and num_text_blocks <= 2:
        return "scanned"
    return "text" if len(text) > 100 else "scanned"

# %% [markdown]
# COMBINED TEXT/SCAN + PAGE_ANALYSIS

# %%
folder_path = r"C:\Users\kaustubh.keny\Documents\Quarterly Results 2026 Q1"

probe_data = []
pdf_data = []

files = [f for f in os.listdir(folder_path) if f.lower().endswith(".pdf")]
total_files = len(files)

for idx, file in enumerate(files):

    print(f"{idx+1}/{total_files}: {file}")

    pdf_path = os.path.join(folder_path, file)
    pdf_file = Path(pdf_path)

    start_t = time.perf_counter()

    text_pages = 0
    scanned_pages = 0

    try:

        with fitz.open(pdf_path) as doc:

            total_pages = doc.page_count

            # Handle empty PDFs
            if total_pages == 0:
                print(f"Empty PDF skipped: {file}")

                pdf_data.append(
                    {
                        "pdf_name": pdf_file.stem,
                        "total_pages": 0,
                        "text_pages": 0,
                        "scanned_pages": 0,
                        "file_size": os.path.getsize(pdf_path),
                        "time_elapsed": 0,
                        "status": "empty_pdf",
                    }
                )
                continue

            ref_page = doc[0]
            rw = ref_page.rect.width
            rh = ref_page.rect.height

            for page_no, page in enumerate(doc):

                page_number = page_no + 1

                layout = page_layout_metadata(page, rw, rh)
                page_type = page_text_or_scanned(page)

                # ==================================================
                # SCANNED PAGE
                # ==================================================
                if page_type == "scanned":

                    scanned_pages += 1

                    probe_data.append(
                        {
                            "pdf": pdf_file.stem,
                            "page_n": page_number,
                            "side": "S",
                            "page_type": "scanned",
                            "width": int(page.rect.width),
                            "height": int(page.rect.height),
                            "spread": layout["spread"],
                            "split_x": layout["split_x"],
                            "line_count": 0,
                            "block_count": 0,
                            "t_dir": None,
                            "numeric_lines": [],
                            "numeric_count": 0,
                            "headline_data": "",
                            "head_match": [],
                            "head_bool": False,
                            "probe_x": [],
                            "probe_y": [],
                            "probe_x_hits": [],
                            "probe_y_hits": [],
                        }
                    )

                    continue

                # ==================================================
                # TEXT PAGE
                # ==================================================
                text_pages += 1

                w = layout["width"]
                h = layout["height"]

                if layout["spread"]:

                    split_x = layout["split_x"]

                    regions = (
                        (
                            {
                                "x0": 0,
                                "y0": 0,
                                "x1": split_x,
                                "y1": h,
                            },
                            "L",
                        ),
                        (
                            {
                                "x0": split_x,
                                "y0": 0,
                                "x1": w,
                                "y1": h,
                            },
                            "R",
                        ),
                    )

                else:

                    regions = (
                        (
                            {
                                "x0": 0,
                                "y0": 0,
                                "x1": w,
                                "y1": h,
                            },
                            "S",
                        ),
                    )

                for region, side in regions:

                    try:

                        metadata = {
                            "pdf": pdf_file.stem,
                            "page_n": page_number,
                            "side": side,
                            "page_type": "text",
                        }

                        metadata.update(
                            page_content_metadata_v1(
                                page,
                                layout,
                                region,
                            )
                        )

                        metadata = page_probe_metadata_v1(metadata)

                        probe_data.append(metadata)

                    except Exception as page_err:

                        print(
                            f"Page processing failed | "
                            f"{file} | Page={page_number} | Side={side}"
                        )
                        print(page_err)

                        continue

        elapsed = time.perf_counter() - start_t

        pdf_data.append(
            {
                "pdf_name": pdf_file.stem,
                "total_pages": total_pages,
                "text_pages": text_pages,
                "scanned_pages": scanned_pages,
                "file_size": os.path.getsize(pdf_path),
                "time_elapsed": round(elapsed, 2),
                "status": "success",
            }
        )

    except Exception as e:

        elapsed = time.perf_counter() - start_t

        print(f"Failed PDF: {file}")
        print(e)

        pdf_data.append(
            {
                "pdf_name": pdf_file.stem,
                "total_pages": None,
                "text_pages": None,
                "scanned_pages": None,
                "file_size": (
                    os.path.getsize(pdf_path) if os.path.exists(pdf_path) else None
                ),
                "time_elapsed": round(elapsed, 2),
                "status": f"failed: {str(e)}",
            }
        )

        continue
# Out:
# 1/3520: 20 Microns Ltd..pdf
# 2/3520: 360 One Wam Ltd..pdf
# 3/3520: 3B Blackbio Dx Ltd..pdf
# 4/3520: 3I Infotech Ltd..pdf
# 5/3520: 3M India Ltd..pdf
# 6/3520: 3P Land Holdings Ltd..pdf
# 7/3520: 5Paisa Capital Ltd..pdf
# 8/3520: 63 Moons Technologies Ltd..pdf
# 9/3520: 7NR Retail Ltd..pdf
# 10/3520: A B Cotspin India Ltd..pdf
# 11/3520: A B Infrabuild Ltd..pdf
# 12/3520: A K Capital Services Ltd..pdf
# 13/3520: A-1 Ltd..pdf
# 14/3520: A2Z Infra Engineering Ltd..pdf
# 15/3520: Aadhar Housing Finance Ltd..pdf
# 16/3520: Aagam Capital Ltd..pdf
# 17/3520: Aananda Lakshmi Spinning Mills Ltd..pdf
# 18/3520: AAR Shyam India Investment Co Ltd..pdf
# 19/3520: Aarcon Facilities.pdf
# 20/3520: Aarnav Fashions Ltd..pdf
# 21/3520: Aartech Solonics Ltd..pdf
# 22/3520: Aarti Drugs Ltd..pdf
# 23/3520: Aarti Industries Ltd..pdf
# 24/3520: Aarti Pharmalabs Ltd..pdf
# 25/3520: Aarti Surfactants Ltd..pdf
# 26/3520: Aarvi Encon Ltd..pdf
# 27/3520: Aastamangalam Finance Ltd..pdf
# 28/3520: Aastha Spintex Ltd..pdf
# 29/3520: Aavas Financiers Ltd..pdf
# 30/3520: Aayush Wellness Ltd..pdf
# 31/3520: Abans Enterprises Ltd..pdf
# 32/3520: Abate As Industries Ltd..pdf
# 33/3520: ABB India Ltd..pdf
# 34/3520: Abbott India Ltd..pdf
# 35/3520: ABC India Ltd..pdf
# 36/3520: Abhinav Capital Services Ltd..pdf
# 37/3520: Abhinav Leasing & Finance Ltd..pdf
# 38/3520: Abhishek Finlease Ltd..pdf
# 39/3520: Abhishek Infraventures Ltd..pdf
# 40/3520: Abirami Financial Services India Ltd..pdf
# 41/3520: ACC Ltd..pdf
# 42/3520: Accedere Ltd..pdf
# 43/3520: Accel Ltd..pdf
# 44/3520: Accelya Solutions India Ltd..pdf
# 45/3520: Accuracy Shipping Ltd..pdf
# 46/3520: ACE Edutrend Ltd..pdf
# 47/3520: Ace Engitech Ltd..pdf
# 48/3520: Ace Men Engg Works Ltd..pdf
# 49/3520: Ace Software Exports Ltd..pdf
# 50/3520: Achyut Healthcare Ltd..pdf
# 51/3520: Acknit Industries Ltd..pdf
# 52/3520: ACME Solar Holdings Ltd..pdf
# 53/3520: ACS Technologies Ltd..pdf
# 54/3520: Action Construction Equipment Ltd..pdf
# 55/3520: Acutaas Chemicals Ltd..pdf
# 56/3520: AD Manum Finance Ltd..pdf
# 57/3520: Adani Energy Solutions Ltd..pdf
# 58/3520: Adani Enterprises Ltd..pdf
# 59/3520: Adani Green Energy Ltd..pdf
# 60/3520: Adani Ports And Special Economic Zone Ltd..pdf
# 61/3520: Adani Power Ltd..pdf
# 62/3520: Adani Total Gas Ltd..pdf
# 63/3520: ADC India Communications Ltd..pdf
# 64/3520: Add-Shop E-Retail Ltd..pdf
# 65/3520: Addi Industries Ltd..pdf
# 66/3520: ADF Foods Ltd..pdf
# 67/3520: Adhata Global Ltd..pdf
# 68/3520: Adhbhut Infrastructure Ltd..pdf
# 69/3520: Adinath Textiles Ltd..pdf
# 70/3520: Aditya Birla Capital Ltd..pdf
# 71/3520: Aditya Birla Fashion And Retail Ltd..pdf
# 72/3520: Aditya Birla Lifestyle Brands Ltd..pdf
# 73/3520: Aditya Birla Money Ltd..pdf
# 74/3520: Aditya Birla Real Estate Ltd..pdf
# 75/3520: Aditya Birla Sun Life AMC Ltd..pdf
# 76/3520: Aditya Infotech Ltd..pdf
# 77/3520: Aditya Vision Ltd..pdf
# 78/3520: Adline Chem Lab Ltd..pdf
# 79/3520: Adon Agro Commodities Ltd..pdf
# 80/3520: Ador Welding Ltd..pdf
# 81/3520: Adroit Infotech Ltd..pdf
# 82/3520: Advait Energy Transitions Ltd..pdf
# 83/3520: Advance Agrolife Ltd..pdf
# 84/3520: Advance Lifestyles Ltd..pdf
# 85/3520: Advance Multitech Ltd..pdf
# 86/3520: Advance Petrochemicals Ltd..pdf
# 87/3520: Advanced Enzyme Technologies Ltd..pdf
# Empty PDF skipped: Advanced Enzyme Technologies Ltd..pdf
# 88/3520: Advent Hotels International Ltd..pdf
# 89/3520: Advik Laboratories Ltd..pdf
# 90/3520: Advit Jewels Ltd..pdf
# 91/3520: Aegis Logistics Ltd..pdf
# 92/3520: Aegis Vopak Terminals Ltd..pdf
# 93/3520: Aeonx Digital Technology Ltd..pdf
# 94/3520: Aequs Ltd..pdf
# 95/3520: Aeroflex Enterprises Ltd..pdf
# 96/3520: Aeroflex Industries Ltd..pdf
# 97/3520: Aeroflex Neu Ltd..pdf
# 98/3520: Aerpace Industries Ltd..pdf
# 99/3520: Aether Industries Ltd..pdf
# 100/3520: Afcons Infrastructure Ltd..pdf
# 101/3520: Affle 3i Ltd..pdf
# 102/3520: Affordable Robotic & Automation Ltd..pdf
# 103/3520: AG Ventures Ltd..pdf
# 104/3520: Agarwal Fortune India Ltd..pdf
# 105/3520: Agarwal Industrial Corp Ltd..pdf
# 106/3520: AGI Greenpac Ltd..pdf
# 107/3520: AGI Infra Ltd..pdf
# 108/3520: AI Champdany Industries Ltd..pdf
# 109/3520: AIA Engineering Ltd..pdf
# 110/3520: Aimco Pesticides Ltd..pdf
# 111/3520: Aion-Tech Solutions Ltd..pdf
# 112/3520: Airan Ltd..pdf
# 113/3520: Ajanta Pharma Ltd..pdf
# 114/3520: Ajanta Soya Ltd..pdf
# 115/3520: Ajax Engineering Ltd..pdf
# 116/3520: AJC Jewel Manufacturers Ltd..pdf
# 117/3520: Ajcon Global Services Ltd..pdf
# 118/3520: Ajmera Realty & Infra India Ltd..pdf
# 119/3520: AJR Infra And Tolling Ltd..pdf
# 120/3520: Ajwa Fun World & Resorts Ltd..pdf
# 121/3520: Akar Auto Industries Ltd..pdf
# 122/3520: AKI India Ltd..pdf
# 123/3520: Akme Fintrade (India) Ltd..pdf
# 124/3520: Akshar Spintex Ltd..pdf
# 125/3520: Aksharchem India Ltd..pdf
# 126/3520: Akums Drugs and Pharmaceuticals Ltd..pdf
# 127/3520: Alacrity Securities Ltd..pdf
# 128/3520: Alan Scott Enterprises Ltd..pdf
# 129/3520: Alankit Ltd..pdf
# 130/3520: Albert David Ltd..pdf
# 131/3520: Alembic Ltd..pdf
# 132/3520: Alembic Pharmaceuticals Ltd..pdf
# 133/3520: Alfa Ica India Ltd..pdf
# 134/3520: Alfa Transformers Ltd..pdf
# 135/3520: Alfred Herbert India Ltd..pdf
# 136/3520: Alicon Castalloy Ltd..pdf
# 137/3520: Alivus Life Sciences Ltd..pdf
# 138/3520: Alkali Metals Ltd..pdf
# 139/3520: Alkyl Amines Chemicals Ltd..pdf
# 140/3520: All Time Plastics Ltd..pdf
# 141/3520: Allcargo Logistics Ltd..pdf
# 142/3520: Allcargo Terminals Ltd..pdf
# 143/3520: Alldigi Tech Ltd..pdf
# 144/3520: Alliance Integrated Metaliks Ltd..pdf
# 145/3520: Allied Blenders And Distillers Ltd..pdf
# 146/3520: Allied Digital Services Ltd..pdf
# 147/3520: Almondz Global Securities Ltd..pdf
# 148/3520: Alna Trading Exports Ltd..pdf
# 149/3520: Alok Industries Ltd..pdf
# 150/3520: Alpa Laboratories Ltd..pdf
# 151/3520: Alphageo India Ltd..pdf
# 152/3520: Alphalogic Techsys Ltd..pdf
# 153/3520: Alpine Housing Development Corp Ltd..pdf
# 154/3520: Alps Industries Ltd..pdf
# 155/3520: Alstone Textiles India Ltd..pdf
# 156/3520: Alufluoride Ltd..pdf
# 157/3520: Amagi Media Labs Ltd..pdf
# 158/3520: Amal Ltd..pdf
# 159/3520: Amalgamated Electricity Co Ltd..pdf
# 160/3520: Amanta Healthcare Ltd..pdf
# 161/3520: Amara Raja Energy & Mobility Ltd..pdf
# 162/3520: Amarjothi Spinning Mills Ltd..pdf
# 163/3520: Amba Enterprises Ltd..pdf
# 164/3520: Ambalal Sarabhai Enterprises Ltd..pdf
# 165/3520: Ambassador Intra Holdings Ltd..pdf
# 166/3520: Amber Enterprises India Ltd..pdf
# 167/3520: Ambika Cotton Mills Ltd..pdf
# 168/3520: Ambitious Plastomac Co Ltd..pdf
# 169/3520: Ambuja Cements Ltd..pdf
# 170/3520: Amco India Ltd..pdf
# 171/3520: AMD Industries Ltd..pdf
# 172/3520: Amerise Biosciences Ltd..pdf
# 173/3520: Amforge Industries Ltd..pdf
# 174/3520: Amir Chand Jagdish Kumar (Exports) Ltd..pdf
# 175/3520: Amit International Ltd..pdf
# 176/3520: Amit Securities Ltd..pdf
# 177/3520: AMJ Land Holdings Ltd..pdf
# 178/3520: Ampvolts Ltd..pdf
# 179/3520: Amraworld Agrico Ltd..pdf
# 180/3520: Amrutanjan Health Care Ltd..pdf
# 181/3520: Ams Polymers Ltd..pdf
# 182/3520: Anand Projects Ltd..pdf
# 183/3520: Anand Rathi Share and Stock Brokers Ltd..pdf
# 184/3520: Anand Rathi Wealth Ltd..pdf
# 185/3520: Anand Rayons Ltd..pdf
# 186/3520: Anant Raj Ltd..pdf
# 187/3520: Andhra Cements Ltd..pdf
# 188/3520: Andhra Paper Ltd..pdf
# 189/3520: Andhra Petrochemicals Ltd..pdf
# 190/3520: Andhra Pradesh Tanneries Ltd..pdf
# 191/3520: Andrew Yule & Company Ltd..pdf
# 192/3520: Anirit Ventures Ltd..pdf
# 193/3520: Anjani Finance Ltd..pdf
# 194/3520: Anjani Foods Ltd..pdf
# 195/3520: Anjani Portland Cement Ltd..pdf
# 196/3520: Anjani Synthetics Ltd..pdf
# 197/3520: Anka India Ltd..pdf
# 198/3520: Anlon Healthcare Ltd..pdf
# 199/3520: Anmol India Ltd..pdf
# 200/3520: Anna Infrastructures Ltd..pdf
# 201/3520: Ansal Buildwell Ltd..pdf
# 202/3520: Ansal Housing Ltd..pdf
# 203/3520: Antariksh Industries Ltd..pdf
# 204/3520: Antelopus Selan Energy Ltd..pdf
# 205/3520: Anthem Biosciences Ltd..pdf
# 206/3520: Anubhav Plast Ltd..pdf
# 207/3520: Anuh Pharma Ltd..pdf
# 208/3520: Anup Engineering Ltd..pdf
# 209/3520: Anupam Finserv Ltd..pdf
# 210/3520: Anupam Rasayan India Ltd..pdf
# 211/3520: Anuroop Packaging Ltd..pdf
# 212/3520: Apar Industries Ltd..pdf
# 213/3520: Apcotex Industries Ltd..pdf
# 214/3520: Apex Capital And Finance Ltd..pdf
# 215/3520: Apex Frozen Foods Ltd..pdf
# 216/3520: Apis India Ltd..pdf
# 217/3520: APL Apollo Tubes Ltd..pdf
# 218/3520: Aplab Ltd..pdf
# 219/3520: APM Industries Ltd..pdf
# 220/3520: Apollo Hospitals Enterprise Ltd..pdf
# 221/3520: Apollo Micro Systems Ltd..pdf
# 222/3520: Apollo Pipes Ltd..pdf
# 223/3520: Apollo Tyres Ltd..pdf
# 224/3520: APT Packaging Ltd..pdf
# 225/3520: Aptech Ltd..pdf
# 226/3520: Aptus Value Housing Finance India Ltd..pdf
# 227/3520: Aqylon Nexus Ltd..pdf
# 228/3520: Aravali Securities & Finance Ltd..pdf
# 229/3520: ARC Finance Ltd..pdf
# 230/3520: Arcee Industries Ltd..pdf
# 231/3520: Archean Chemical Industries Ltd..pdf
# 232/3520: Archidply Industries Ltd..pdf
# 233/3520: Archit Organosys Ltd..pdf
# 234/3520: ARCL Organics Ltd..pdf
# 235/3520: Arco Leasing Ltd..pdf
# 236/3520: Arcotech Ltd..pdf
# 237/3520: Ardi Investment & Trading Ltd..pdf
# 238/3520: Arex Industries Ltd..pdf
# 239/3520: Arfin India Ltd..pdf
# 240/3520: Aries Agro Ltd..pdf
# 241/3520: Arigato Universe Ltd..pdf
# 242/3520: Arihant Capital Markets Ltd..pdf
# 243/3520: Arihant Foundations & Housing Ltd..pdf
# 244/3520: Arihant Superstructures Ltd..pdf
# 245/3520: Arihants Securities Ltd..pdf
# 246/3520: Arisinfra Solutions Ltd..pdf
# 247/3520: Arkade Developers Ltd..pdf
# 248/3520: Arman Financial Services Ltd..pdf
# 249/3520: Arman Holdings Ltd..pdf
# 250/3520: Arnold Holdings Ltd..pdf
# 251/3520: ARO Granite Industries Ltd..pdf
# 252/3520: Arrow Greentech Ltd..pdf
# 253/3520: Artefact Projects Ltd..pdf
# 254/3520: Artemis Electricals And Projects Ltd..pdf
# 255/3520: Artemis Medicare Services Ltd..pdf
# 256/3520: Artificial Electronics Intelligent Material Ltd..pdf
# 257/3520: Aruna Hotels Ltd..pdf
# 258/3520: Arunjyoti Bio Ventures Ltd..pdf
# 259/3520: Arvaya Healthcare Ltd..pdf
# 260/3520: Arvind Fashions Ltd..pdf
# 261/3520: Arvind Ltd..pdf
# 262/3520: Arvind Smartspaces Ltd..pdf
# 263/3520: Aryaman Capital Markets Ltd..pdf
# 264/3520: Aryan Shares And Stock Brokers Ltd..pdf
# 265/3520: Asahi India Glass Ltd..pdf
# 266/3520: Asahi Songwon Colors Ltd..pdf
# 267/3520: Asarfi Hospital Ltd..pdf
# 268/3520: Ashapura Intimates Fashion Ltd..pdf
# 269/3520: Ashapura Minechem Ltd..pdf
# 270/3520: Ashiana Agro Industries Ltd..pdf
# 271/3520: Ashiana Housing Ltd..pdf
# 272/3520: Ashika Global Securities Ltd..pdf
# 273/3520: Ashima Ltd..pdf
# 274/3520: Ashirwad Capital Ltd..pdf
# 275/3520: Ashirwad Steels & Industries Ltd..pdf
# 276/3520: Ashish Polyplast Ltd..pdf
# 277/3520: Ashnoor Textile Mills Ltd..pdf
# 278/3520: Ashoka Buildcon Ltd..pdf
# 279/3520: Ashoka Metcast Ltd..pdf
# 280/3520: Ashoka Refineries Ltd..pdf
# 281/3520: Ashutosh Paper Mills Ltd..pdf
# 282/3520: ASI Industries Ltd..pdf
# 283/3520: Asia Capital Ltd..pdf
# 284/3520: Asia Pack Ltd..pdf
# 285/3520: Asian Energy Services Ltd..pdf
# 286/3520: Asian Fertilizers Ltd..pdf
# 287/3520: Asian Granito India Ltd..pdf
# 288/3520: Asian Hotels (East) Ltd..pdf
# 289/3520: Asian Paints Ltd..pdf
# 290/3520: Asian Petroproducts & Exports Ltd..pdf
# 291/3520: Asian Star Co Ltd..pdf
# 292/3520: Asian Tea & Exports Ltd..pdf
# 293/3520: Asit C Mehta Financial Services Ltd..pdf
# 294/3520: Ask Automotive Ltd..pdf
# 295/3520: ASM Technologies Ltd..pdf
# 296/3520: Aspira Pathlab & Diagnostics Ltd..pdf
# 297/3520: Assam Entrade Ltd..pdf
# 298/3520: Associated Alcohols & Breweries Ltd..pdf
# 299/3520: Astec Lifesciences Ltd..pdf
# 300/3520: Aster DM Quality Care Ltd..pdf
# 301/3520: Astonea Labs Ltd..pdf
# 302/3520: Astra Microwave Products Ltd..pdf
# 303/3520: Astral Ltd..pdf
# 304/3520: Astrazeneca Pharma India Ltd..pdf
# 305/3520: Asutosh Enterprises Ltd..pdf
# 306/3520: Atal Realtech Ltd..pdf
# 307/3520: Atam Valves Ltd..pdf
# 308/3520: Atharv Enterprises Ltd..pdf
# 309/3520: Atharva Poly-Plast Ltd..pdf
# 310/3520: Ather Energy Ltd..pdf
# 311/3520: Atishay Ltd..pdf
# 312/3520: Atlanta Electricals Ltd..pdf
# 313/3520: Atlantaa Ltd..pdf
# 314/3520: Atlas Cycles (Haryana) Ltd..pdf
# 315/3520: ATN International Ltd..pdf
# 316/3520: Atul Auto Ltd..pdf
# 317/3520: Atul Ltd..pdf
# 318/3520: ATV Projects India Ltd..pdf
# 319/3520: ATVO Enterprises Ltd..pdf
# 320/3520: AU Small Finance Bank Ltd..pdf
# 321/3520: AUDROC Ltd..pdf
# 322/3520: Aurionpro Solutions Ltd..pdf
# 323/3520: Aurobindo Pharma Ltd..pdf
# 324/3520: Aurum Proptech Ltd..pdf
# 325/3520: Ausom Enterprise Ltd..pdf
# 326/3520: Austin Engineering Co Ltd..pdf
# 327/3520: Authum Investment & Infrastructure Ltd..pdf
# 328/3520: Auto Pins India Ltd..pdf
# 329/3520: Autoline Industries Ltd..pdf
# 330/3520: Automobile Corp Of Goa Ltd..pdf
# 331/3520: Automobile Products India Ltd..pdf
# 332/3520: Automotive Axles Ltd..pdf
# 333/3520: Automotive Stampings and Assemblies Ltd..pdf
# 334/3520: Autoriders International Ltd..pdf
# 335/3520: Avadh Sugar & Energy Ltd..pdf
# 336/3520: Avalon Technologies Ltd..pdf
# 337/3520: Avance Technologies Ltd..pdf
# 338/3520: Avantel Ltd..pdf
# Empty PDF skipped: Avantel Ltd..pdf
# 339/3520: Avanti Feeds Ltd..pdf
# 340/3520: Aveer Foods Ltd..pdf
# 341/3520: Avenue Supermarts Ltd..pdf
# 342/3520: Avenuesai Ltd..pdf
# 343/3520: AVI Polymers Ltd..pdf
# 344/3520: Avi Products India Ltd..pdf
# 345/3520: Avio Smart Market Stack Ltd..pdf
# 346/3520: Avishkar Infra Realty Ltd..pdf
# 347/3520: Aviva Industries Ltd..pdf
# 348/3520: Avonmore Capital & Management Services Ltd..pdf
# 349/3520: AVT Natural Products Ltd..pdf
# 350/3520: Awfis Space Solutions Ltd..pdf
# 351/3520: Awl Agri Business Ltd..pdf
# 352/3520: Axis Bank Ltd..pdf
# 353/3520: Axis Solutions Ltd..pdf
# 354/3520: Axiscades Technologies Ltd..pdf
# 355/3520: Axita Cotton Ltd..pdf
# 356/3520: Axtel Industries Ltd..pdf
# 357/3520: Aye Finance Ltd..pdf
# 358/3520: Aym Syntex Ltd..pdf
# 359/3520: Azad Engineering Ltd..pdf
# 360/3520: Azad India Mobility Ltd..pdf
# 361/3520: B & A Ltd..pdf
# 362/3520: B&A Packaging India Ltd..pdf
# 363/3520: B. L. Kashyap and Sons Ltd..pdf
# 364/3520: B.A.G Films and Media Ltd..pdf
# 365/3520: B2B Software Technologies Ltd..pdf
# 366/3520: Baazar Style Retail Ltd..pdf
# 367/3520: Baba Arts Ltd..pdf
# 368/3520: Bacil Pharma Ltd..pdf
# 369/3520: Bafna Pharmaceuticals Ltd..pdf
# 370/3520: Baid Finserv Ltd..pdf
# 371/3520: Bajaj Auto Ltd..pdf
# 372/3520: Bajaj Consumer Care Ltd..pdf
# 373/3520: Bajaj Electricals Ltd..pdf
# 374/3520: Bajaj Finance Ltd..pdf
# 375/3520: Bajaj Finserv Ltd..pdf
# 376/3520: Bajaj Global Ltd..pdf
# 377/3520: Bajaj Healthcare Ltd..pdf
# 378/3520: Bajaj Hindusthan Sugar Ltd..pdf
# 379/3520: Bajaj Holdings & Investment Ltd..pdf
# 380/3520: Bajaj Housing Finance Ltd..pdf
# 381/3520: Bajel Projects Ltd..pdf
# 382/3520: Bal Pharma Ltd..pdf
# 383/3520: Balaji Amines Ltd..pdf
# 384/3520: Balaji Telefilms Ltd..pdf
# 385/3520: Balgopal Commercial Ltd..pdf
# 386/3520: Balkrishna Industries Ltd..pdf
# 387/3520: Balkrishna Paper Mills Ltd..pdf
# 388/3520: Balmer Lawrie & Company Ltd..pdf
# 389/3520: Balmer Lawrie Investments Ltd..pdf
# 390/3520: Balrampur Chini Mills Ltd..pdf
# 391/3520: Balu Forge Industries Ltd..pdf
# 392/3520: Balurghat Technologies Ltd..pdf
# 393/3520: Bambino Agro Industries Ltd..pdf
# 394/3520: BAMPSL Securities Ltd..pdf
# 395/3520: Banaras Beads Ltd..pdf
# 396/3520: Banco Products (I) Ltd..pdf
# 397/3520: Bandaram Pharma Packtech Ltd..pdf
# 398/3520: Bandhan Bank Ltd..pdf
# 399/3520: Bank Of Baroda.pdf
# 400/3520: Bank Of India.pdf
# 401/3520: Bank Of Maharashtra.pdf
# 402/3520: Bannari Amman Spinning Mills Ltd..pdf
# 403/3520: Bansal Roofing Products Ltd..pdf
# 404/3520: Bansal Wire Industries Ltd..pdf
# 405/3520: Banswara Syntex Ltd..pdf
# 406/3520: Barak Valley Cements Ltd..pdf
# 407/3520: Baroda Extrusion Ltd..pdf
# 408/3520: Basant Agro Tech India Ltd..pdf
# 409/3520: BASF India Ltd..pdf
# 410/3520: Bata India Ltd..pdf
# 411/3520: Batliboi Ltd..pdf
# 412/3520: Bayer Cropscience Ltd..pdf
# 413/3520: BC Power Controls Ltd..pdf
# 414/3520: BCC Fuba India Ltd..pdf
# 415/3520: BCL Industries Ltd..pdf
# 416/3520: Bedmutha Industries Ltd..pdf
# 417/3520: Beekay Steel Industries Ltd..pdf
# 418/3520: Beeyu Overseas Ltd..pdf
# 419/3520: Belding India Ltd..pdf
# 420/3520: Bella Casa Fashion & Retail Ltd..pdf
# 421/3520: Bemco Hydraulics Ltd..pdf
# 422/3520: Beml Land Assets Ltd..pdf
# 423/3520: BEML Ltd..pdf
# 424/3520: Benares Hotels Ltd..pdf
# 425/3520: Bengal & Assam Co Ltd..pdf
# 426/3520: Bengal Steel Industries Ltd..pdf
# 427/3520: Bengal Tea & Fabrics Ltd..pdf
# 428/3520: Bentley Commercial Enterprises Ltd..pdf
# 429/3520: Berger Paints India Ltd..pdf
# 430/3520: Bervin Investment & Leasing Ltd..pdf
# 431/3520: Beryl Drugs Ltd..pdf
# 432/3520: Beryl Securities Ltd..pdf
# 433/3520: Best Agrolife Ltd..pdf
# 434/3520: Best Eastern Hotels Ltd..pdf
# 435/3520: Betala Global Securities Ltd..pdf
# 436/3520: BF Utilities Ltd..pdf
# 437/3520: BFL Asset Finvest Ltd..pdf
# 438/3520: BGR Energy Systems Ltd..pdf
# 439/3520: Bhageria Industries Ltd..pdf
# 440/3520: Bhagiradha Chemicals & Industries Ltd..pdf
# 441/3520: Bhagwati Autocast Ltd..pdf
# 442/3520: Bhagyanagar India Ltd..pdf
# 443/3520: Bhandari Hosiery Exports Ltd..pdf
# 444/3520: Bhansali Engineering Polymers Ltd..pdf
# 445/3520: Bharat Agri Fert & Realty Ltd..pdf
# 446/3520: Bharat Bhushan Share & Commodity Brokers Ltd..pdf
# 447/3520: Bharat Bijlee Ltd..pdf
# 448/3520: Bharat Coking Coal Ltd..pdf
# 449/3520: Bharat Electronics Ltd..pdf
# 450/3520: Bharat Forge Ltd..pdf
# 451/3520: Bharat Gears Ltd..pdf
# 452/3520: Bharat Global Developers Ltd..pdf
# Empty PDF skipped: Bharat Global Developers Ltd..pdf
# 453/3520: Bharat Heavy Electricals Ltd..pdf
# 454/3520: Bharat Parenterals Ltd..pdf
# 455/3520: Bharat Petroleum Corp Ltd..pdf
# 456/3520: Bharat Seats Ltd..pdf
# 457/3520: Bharat Textiles & Proofing Industries Ltd..pdf
# 458/3520: Bharat Wire Ropes Ltd..pdf
# 459/3520: Bharti Airtel Ltd..pdf
# 460/3520: Bharti Hexacom Ltd..pdf
# 461/3520: Bhartiya International Ltd..pdf
# 462/3520: Bhilwara Spinners Ltd..pdf
# 463/3520: Bhilwara Technical Textiles Ltd..pdf
# 464/3520: Bigbloc Construction Ltd..pdf
# 465/3520: Bikaji Foods International Ltd..pdf
# 466/3520: Bilcare Ltd..pdf
# 467/3520: Billionbrains Garage Ventures Ltd..pdf
# 468/3520: Bimetal Bearings Ltd..pdf
# 469/3520: Binayak Tex Processors Ltd..pdf
# 470/3520: Binny Ltd..pdf
# 471/3520: Binny Mills Ltd..pdf
# 472/3520: Biocon Ltd..pdf
# 473/3520: Biofil Chemicals & Pharmaceuticals Ltd..pdf
# 474/3520: Biogen Pharmachem Industries Ltd..pdf
# 475/3520: Birla Cable Ltd..pdf
# 476/3520: Birla Capital & Financial Services Ltd..pdf
# 477/3520: Birla Corp Ltd..pdf
# 478/3520: Birla Cotsyn (India) Ltd..pdf
# 479/3520: Birla Precision Technologies Ltd..pdf
# 480/3520: Birla Transasia Carpets Ltd..pdf
# 481/3520: Birlanu Ltd..pdf
# 482/3520: Birlasoft Ltd..pdf
# 483/3520: Bits Ltd..pdf
# 484/3520: BKM Industries Ltd..pdf
# 485/3520: BKV Industries Ltd..pdf
# 486/3520: Black Box Ltd..pdf
# 487/3520: Black Rose Industries Ltd..pdf
# 488/3520: Blackbuck Ltd..pdf
# 489/3520: BLB Ltd..pdf
# 490/3520: Bliss Gvs Pharma Ltd..pdf
# 491/3520: Bloom Industries Ltd..pdf
# 492/3520: Bls E-Services Ltd..pdf
# 493/3520: BLS Infotech Ltd..pdf
# 494/3520: BLS International Services Ltd..pdf
# 495/3520: Blue Chip Tex Industries Ltd..pdf
# 496/3520: Blue Coast Hotels Ltd..pdf
# 497/3520: Blue Dart Express Ltd..pdf
# 498/3520: Blue Jet Healthcare Ltd..pdf
# 499/3520: Blue Pearl Agriventures Ltd..pdf
# 500/3520: Blue Star Ltd..pdf
# 501/3520: Bluestone Jewellery And Lifestyle Ltd..pdf
# 502/3520: Bluspring Enterprises Ltd..pdf
# 503/3520: BMW Ventures Ltd..pdf
# 504/3520: BN Agrochem Ltd..pdf
# 505/3520: BN Rathi Securities Ltd..pdf
# 506/3520: BNR Udyog Ltd..pdf
# 507/3520: Bodal Chemicals Ltd..pdf
# 508/3520: Bodhi Tree Multimedia Ltd..pdf
# 509/3520: Bodhtree Consulting Ltd..pdf
# 510/3520: Bombay Burmah Trading Corporation Ltd..pdf
# 511/3520: Bombay Cycle & Motor Agency Ltd..pdf
# 512/3520: Bombay Potteries & Tiles Ltd..pdf
# 513/3520: Bombay Super Hybrid Seeds Ltd..pdf
# 514/3520: Bombay Talkies Ltd..pdf
# 515/3520: Bombay Wire Ropes Ltd..pdf
# 516/3520: Bondada Engineering Ltd..pdf
# 517/3520: Borana Weaves Ltd..pdf
# 518/3520: Borosil Renewables Ltd..pdf
# 519/3520: Borosil Scientific Ltd..pdf
# 520/3520: Bosch Home Comfort India Ltd..pdf
# 521/3520: BP Capital Ltd..pdf
# 522/3520: BPL Ltd..pdf
# 523/3520: Brady & Morris Engineering Co Ltd..pdf
# 524/3520: Brahmaputra Infrastructure Ltd..pdf
# 525/3520: Brainbees Solutions Ltd..pdf
# 526/3520: Brand Concepts Ltd..pdf
# 527/3520: Brandbucket Media & Technology Ltd..pdf
# 528/3520: Brawn Biotech Ltd..pdf
# 529/3520: Brigade Enterprises Ltd..pdf
# 530/3520: Brigade Hotel Ventures Ltd..pdf
# 531/3520: Bright Brothers Ltd..pdf
# 532/3520: Brijlaxmi Leasing & Finance Ltd..pdf
# 533/3520: Brilliant Portfolios Ltd..pdf
# 534/3520: Britannia Industries Ltd..pdf
# 535/3520: Brooks Laboratories Ltd..pdf
# 536/3520: Bsel Algo Ltd..pdf
# 537/3520: BSL Ltd..pdf
# 538/3520: Burnpur Cement Ltd..pdf
# 539/3520: Butterfly Gandhimathi Appliances Ltd..pdf
# 540/3520: BWL Ltd..pdf
# 541/3520: Byke Hospitality Ltd..pdf
# 542/3520: BYLD Capital Finance Ltd..pdf
# 543/3520: C & C Constructions Ltd..pdf
# 544/3520: C.E. Info Systems Ltd..pdf
# 545/3520: Calcom Vision Ltd..pdf
# 546/3520: Caliber Mining and Logistics Ltd..pdf
# 547/3520: California Software Company Ltd..pdf
# 548/3520: Callista Industries Ltd..pdf
# 549/3520: Camex Ltd..pdf
# 550/3520: Camlin Fine Sciences Ltd..pdf
# 551/3520: Campus Activewear Ltd..pdf
# 552/3520: Can Fin Homes Ltd..pdf
# 553/3520: Canara Bank.pdf
# 554/3520: Canara HSBC Life Insurance Company Ltd..pdf
# 555/3520: Canara Robeco Asset Management Company Ltd..pdf
# 556/3520: Candour Techtex Ltd..pdf
# 557/3520: Cantabil Retail India Ltd..pdf
# 558/3520: Capacite Infraprojects Ltd..pdf
# 559/3520: Capfin India Ltd..pdf
# 560/3520: Capillary Technologies India Ltd..pdf
# 561/3520: Capital Small Finance Bank Ltd..pdf
# 562/3520: Capital Trade Links Ltd..pdf
# 563/3520: Capital Trust Ltd..pdf
# 564/3520: Caplin Point Laboratories Ltd..pdf
# 565/3520: Capri Global Capital Ltd..pdf
# 566/3520: Capricorn Systems Global Solutions Ltd..pdf
# 567/3520: Caprihans India Ltd..pdf
# 568/3520: Caprolactam Chemicals Ltd..pdf
# 569/3520: Captain Pipes Ltd..pdf
# 570/3520: Captain Polyplast Ltd..pdf
# 571/3520: Carborundum Universal Ltd..pdf
# 572/3520: CARE Ratings Ltd..pdf
# 573/3520: Career Point Edutech Ltd..pdf
# 574/3520: Carnation Industries Ltd..pdf
# 575/3520: Carraro India Ltd..pdf
# 576/3520: Cartrade Tech Ltd..pdf
# 577/3520: Carysil Ltd..pdf
# 578/3520: Caspian Corporate Services Ltd..pdf
# 579/3520: Castora Agri Commodities Ltd..pdf
# 580/3520: Castrol India Ltd..pdf
# 581/3520: Catvision Ltd..pdf
# 582/3520: CCL Products India Ltd..pdf
# 583/3520: CDG Petchem Ltd..pdf
# 584/3520: CEAT Ltd..pdf
# 585/3520: Ceenik Exports India Ltd..pdf
# 586/3520: Ceeta Industries Ltd..pdf
# 587/3520: Ceigall India Ltd..pdf
# 588/3520: Ceinsys Tech Ltd..pdf
# 589/3520: Celebrity Fashions Ltd..pdf
# 590/3520: Cella Space Ltd..pdf
# 591/3520: Cello World Ltd..pdf
# 592/3520: Cemantic Infra-Tech Ltd..pdf
# 593/3520: Cemindia Projects Ltd..pdf
# 594/3520: Cenlub Industries Ltd..pdf
# 595/3520: Centerac Technologies Ltd..pdf
# 596/3520: Central Bank Of India.pdf
# 597/3520: Central Mine Planning & Design Institute Ltd..pdf
# 598/3520: Centrum Capital Ltd..pdf
# 599/3520: Centum Electronics Ltd..pdf
# 600/3520: Centuple Global Ltd..pdf
# 601/3520: Century Enka Ltd..pdf
# 602/3520: Century Plyboards (India) Ltd..pdf
# 603/3520: Cera Sanitaryware Ltd..pdf
# 604/3520: Cerebra Integrated Technologies Ltd..pdf
# 605/3520: CESC Ltd..pdf
# 606/3520: CG Power And Industrial Solutions Ltd..pdf
# 607/3520: CG Vak Software & Exports Ltd..pdf
# 608/3520: Chalet Hotels Ltd..pdf
# 609/3520: Chaman Lal Setia Exports Ltd..pdf
# 610/3520: Chambal Breweries & Distilleries Ltd..pdf
# 611/3520: Chambal Fertilisers & Chemicals Ltd..pdf
# 612/3520: Chandra Prabhu International Ltd..pdf
# 613/3520: Chandrima Mercantiles Ltd..pdf
# 614/3520: Chartered Logistics Ltd..pdf
# 615/3520: Chembond Chemicals Ltd..pdf
# 616/3520: Chembond Material Technologies Ltd..pdf
# 617/3520: Chemcon Speciality Chemicals Ltd..pdf
# 618/3520: Chemcrux Enterprises Ltd..pdf
# 619/3520: Chemfab Alkalis Ltd..pdf
# 620/3520: Chemiesynth (Vapi) Ltd..pdf
# 621/3520: Chemplast Sanmar Ltd..pdf
# 622/3520: Chemtech Industrial Valves Ltd..pdf
# 623/3520: Chennai Ferrous Industries Ltd..pdf
# 624/3520: Chennai Meenakshi Multispeciality Hospital Ltd..pdf
# 625/3520: Chennai Petroleum Corp Ltd..pdf
# 626/3520: Cheviot Company Ltd..pdf
# 627/3520: CHL Ltd..pdf
# 628/3520: Choksi Asia Ltd..pdf
# 629/3520: Choksi Laboratories Ltd..pdf
# 630/3520: Cholamandalam Financial Holdings Ltd..pdf
# 631/3520: Cholamandalam Investment and Finance Company Ltd..pdf
# 632/3520: Chordia Food Products Ltd..pdf
# 633/3520: Chowgule Steamships Ltd..pdf
# 634/3520: CIE Automotive India Ltd..pdf
# 635/3520: Cineline India Ltd..pdf
# 636/3520: Cinevista Ltd..pdf
# 637/3520: Cipla Ltd..pdf
# 638/3520: Cistro Telelink Ltd..pdf
# 639/3520: Citadel Realty Developers Ltd..pdf
# 640/3520: Citi Port Financial Services Ltd..pdf
# 641/3520: Citizen Solar Ltd..pdf
# 642/3520: Citurgia Biochemicals Ltd..pdf
# 643/3520: City Pulse Multiventures Ltd..pdf
# 644/3520: City Union Bank Ltd..pdf
# 645/3520: Cityman Ltd..pdf
# 646/3520: CL Educate Ltd..pdf
# 647/3520: Classic Electricals Ltd..pdf
# 648/3520: Classic Filaments Ltd..pdf
# 649/3520: Classic Leasing & Finance Ltd..pdf
# 650/3520: CLC Industries Ltd..pdf
# 651/3520: Clean Max Enviro Energy Solutions Ltd..pdf
# 652/3520: Clean Science And Technology Ltd..pdf
# 653/3520: Clenon Enterprises Ltd..pdf
# 654/3520: Clio Infotech Ltd..pdf
# 655/3520: CMR Green Technologies Ltd..pdf
# 656/3520: Coal India Ltd..pdf
# 657/3520: Coastal Corporation Ltd..pdf
# 658/3520: Coastal Roadways Ltd..pdf
# 659/3520: Cochin Malabar Estates & Industries Ltd..pdf
# 660/3520: Cochin Minerals & Rutiles Ltd..pdf
# 661/3520: Coffee Day Enterprises Ltd..pdf
# 662/3520: Coforge Ltd..pdf
# 663/3520: Cohance Lifesciences Ltd..pdf
# 664/3520: Colab Platforms Ltd..pdf
# 665/3520: Colgate Palmolive (India) Ltd..pdf
# 666/3520: Colinz Laboratories Ltd..pdf
# 667/3520: Comfort Commotrade Ltd..pdf
# 668/3520: Comfort Fincap Ltd..pdf
# 669/3520: Comfort Intech Ltd..pdf
# 670/3520: Commercial Syn Bags Ltd..pdf
# 671/3520: Compucom Software Ltd..pdf
# 672/3520: Computer Age Management Services Ltd..pdf
# 673/3520: Computer Point Ltd..pdf
# 674/3520: Conart Engineers Ltd..pdf
# 675/3520: Concord Biotech Ltd..pdf
# 676/3520: Concord Enviro Systems Ltd..pdf
# 677/3520: Confidence Futuristic Energetech Ltd..pdf
# 678/3520: Confidence Petroleum India Ltd..pdf
# 679/3520: Consecutive Commodities Ltd..pdf
# 680/3520: Consolidated Construction Consortium Ltd..pdf
# 681/3520: Constronics Infra Ltd..pdf
# 682/3520: Container Corporation of India Ltd..pdf
# 683/3520: Containerway International Ltd..pdf
# 684/3520: Contil India Ltd..pdf
# 685/3520: Continental Chemicals Ltd..pdf
# 686/3520: Continental Controls Ltd..pdf
# 687/3520: Continental Petroleums Ltd..pdf
# 688/3520: Continental Securities Ltd..pdf
# 689/3520: Control Print Ltd..pdf
# 690/3520: Coral India Finance & Housing Ltd..pdf
# 691/3520: Coral Newsprints Ltd..pdf
# 692/3520: Cords Cable Industries Ltd..pdf
# 693/3520: Coromandel Agro Products & Oils Ltd..pdf
# 694/3520: Coromandel Engineering Company Ltd..pdf
# 695/3520: Coromandel International Ltd..pdf
# 696/3520: Corona Remedies Ltd..pdf
# 697/3520: Corporate Merchant Bankers Ltd..pdf
# 698/3520: Cosmo Ferrites Ltd..pdf
# 699/3520: Cosmo First Ltd..pdf
# 700/3520: Cosyn Ltd..pdf
# 701/3520: Country Club Hospitality & Holidays Ltd..pdf
# 702/3520: Country Condos Ltd..pdf
# 703/3520: CP Capital Ltd..pdf
# 704/3520: Craftsman Automation Ltd..pdf
# 705/3520: Crane Infrastructure Ltd..pdf
# 706/3520: Cranex Ltd..pdf
# 707/3520: Cravatex Ltd..pdf
# 708/3520: Creative Castings Ltd..pdf
# 709/3520: Creative Eye Ltd..pdf
# 710/3520: Creative Newtech Ltd..pdf
# 711/3520: Creditaccess Grameen Ltd..pdf
# 712/3520: Credo Brands Marketing Ltd..pdf
# 713/3520: Cresanto Global Ltd..pdf
# 714/3520: Crescentis Capital Ltd..pdf
# 715/3520: Crest Ventures Ltd..pdf
# 716/3520: Crestchem Ltd..pdf
# 717/3520: Crimson Metal Engineering Co Ltd..pdf
# 718/3520: Crisil Ltd..pdf
# 719/3520: Crizac Ltd..pdf
# 720/3520: Croissance Ltd..pdf
# 721/3520: Crompton Greaves Consumer Electrical Ltd..pdf
# 722/3520: Crysdale Industries Ltd..pdf
# 723/3520: Crystal Business System Ltd..pdf
# 724/3520: CSB Bank Ltd..pdf
# 725/3520: CSL Finance Ltd..pdf
# 726/3520: CSM Technologies Ltd..pdf
# 727/3520: Cubex Tubings Ltd..pdf
# 728/3520: Cubical Financial Services Ltd..pdf
# 729/3520: Cummins India Ltd..pdf
# 730/3520: Cupid Breweries And Distilleries Ltd..pdf
# 731/3520: Cupid Ltd..pdf
# 732/3520: Cura Technologies Ltd..pdf
# 733/3520: Cybele Industries Ltd..pdf
# 734/3520: Cyber Media India Ltd..pdf
# 735/3520: Cybertech Systems & Software Ltd..pdf
# 736/3520: Cyient DLM Ltd..pdf
# 737/3520: Cyient Ltd..pdf
# 738/3520: D&H India Ltd..pdf
# 739/3520: D-Link (India) Ltd..pdf
# 740/3520: D. P. Abhushan Ltd..pdf
# 741/3520: D.B. Corp Ltd..pdf
# 742/3520: Dabur India Ltd..pdf
# 743/3520: Dachepalli Publishers Ltd..pdf
# 744/3520: DAI-ICHI Karkaria Ltd..pdf
# 745/3520: Daikaffil Chemicals India Ltd..pdf
# 746/3520: Dalal Street Investments Ltd..pdf
# 747/3520: Dalmia Bharat Ltd..pdf
# 748/3520: Dalmia Bharat Sugar And Industries Ltd..pdf
# 749/3520: DAM Capital Advisors Ltd..pdf
# 750/3520: Damodar Industries Ltd..pdf
# 751/3520: Danlaw Technologies India Ltd..pdf
# 752/3520: Darshan Orna Ltd..pdf
# 753/3520: Data Patterns (India) Ltd..pdf
# 754/3520: Datamatics Global Services Ltd..pdf
# 755/3520: Daulat Securities Ltd..pdf
# 756/3520: DCB Bank Ltd..pdf
# 757/3520: DCM Financial Services Ltd..pdf
# 758/3520: DCM Ltd..pdf
# 759/3520: DCM Nouvelle Ltd..pdf
# 760/3520: DCM Shriram Industries Ltd..pdf
# 761/3520: DCM Shriram Ltd..pdf
# 762/3520: DCW Ltd..pdf
# 763/3520: DCX Systems Ltd..pdf
# 764/3520: DE Nora India Ltd..pdf
# 765/3520: Deccan Cements Ltd..pdf
# 766/3520: Deccan Gold Mines Ltd..pdf
# 767/3520: Deccan Polypacks Ltd..pdf
# 768/3520: Decillion Finance Ltd..pdf
# 769/3520: Decipher Labs Ltd..pdf
# 770/3520: Decorous Investment & Trading Co Ltd..pdf
# 771/3520: DEE Development Engineers Ltd..pdf
# 772/3520: Deep Health AI India Ltd..pdf
# 773/3520: Deep Industries Ltd..pdf
# 774/3520: Deep Polymers Ltd..pdf
# 775/3520: Deepak Fertilisers & Petrochemicals Corp Ltd..pdf
# 776/3520: Deepak Nitrite Ltd..pdf
# 777/3520: Deepak Spinners Ltd..pdf
# 778/3520: Delhivery Ltd..pdf
# 779/3520: Delta Corp Ltd..pdf
# 780/3520: Delta Industrial Resources Ltd..pdf
# 781/3520: Delta Manufacturing Ltd..pdf
# 782/3520: Delton Cables Ltd..pdf
# 783/3520: Den Networks Ltd..pdf
# 784/3520: Denis Chem Lab Ltd..pdf
# 785/3520: Denta Water and Infra Solutions Ltd..pdf
# 786/3520: Desh Rakshak Aushdhalaya Ltd..pdf
# 787/3520: Desi Farms India Ltd..pdf
# 788/3520: Dev Accelerator Ltd..pdf
# 789/3520: Dev Information Technology Ltd..pdf
# 790/3520: Devine Impex Ltd..pdf
# 791/3520: Devyani International Ltd..pdf
# 792/3520: Dhabriya Polywood Ltd..pdf
# 793/3520: Dhampur Bio Organics Ltd..pdf
# 794/3520: Dhampur Sugar Mills Ltd..pdf
# 795/3520: Dhampure Speciality Sugars Ltd..pdf
# 796/3520: Dhanalaxmi Roto Spinners Ltd..pdf
# 797/3520: Dhanashree Electronics Ltd..pdf
# 798/3520: Dhanlaxmi Bank Ltd..pdf
# 799/3520: Dhanlaxmi Cotex Ltd..pdf
# 800/3520: Dhansafal Finserve Ltd..pdf
# 801/3520: Dhanuka Agritech Ltd..pdf
# 802/3520: Dhanvantri Jeevan Rekha Ltd..pdf
# 803/3520: Dharmaj Crop Guard Ltd..pdf
# 804/3520: Dhatre Udyog Ltd..pdf
# 805/3520: Dhoot Industrial Finance Ltd..pdf
# 806/3520: DHP India Ltd..pdf
# 807/3520: Dhruv Consultancy Services Ltd..pdf
# 808/3520: Dhruva Capital Services Ltd..pdf
# 809/3520: Dhunseri Investments Ltd..pdf
# 810/3520: Dhunseri Tea & Industries Ltd..pdf
# 811/3520: Dhunseri Ventures Ltd..pdf
# 812/3520: Diamant Infrastructure Ltd..pdf
# 813/3520: Diamines & Chemicals Ltd..pdf
# 814/3520: Diamond Power Infrastructure Ltd..pdf
# 815/3520: Diana Tea Co Ltd..pdf
# 816/3520: DIC India Ltd..pdf
# 817/3520: Diffusion Engineers Ltd..pdf
# 818/3520: Digicontent Ltd..pdf
# 819/3520: Digidrive Distributors Ltd..pdf
# 820/3520: Digispice Technologies Ltd..pdf
# 821/3520: Digitide Solutions Ltd..pdf
# 822/3520: Digjam Ltd..pdf
# 823/3520: Diligent Media Corp Ltd..pdf
# 824/3520: Dipna Pharmachem Ltd..pdf
# 825/3520: Disa India Ltd..pdf
# 826/3520: Dish Tv India Ltd..pdf
# 827/3520: Disha Resources Ltd..pdf
# 828/3520: Divgi Torqtransfer Systems Ltd..pdf
# 829/3520: Divis Laboratories Ltd..pdf
# 830/3520: Divyashakti Ltd..pdf
# 831/3520: Dixon Technologies India Ltd..pdf
# 832/3520: DLF Ltd..pdf
# 833/3520: DMCC Speciality Chemicals Ltd..pdf
# 834/3520: Dodla Dairy Ltd..pdf
# 835/3520: Dolfin Rubbers Ltd..pdf
# 836/3520: Dolphin Offshore Enterprises (India) Ltd..pdf
# 837/3520: DOMS Industries Ltd..pdf
# 838/3520: Dr Agarwals Eye Hospital Ltd..pdf
# 839/3520: Dr Reddys Laboratories Ltd..pdf
# 840/3520: Dr. Agarwal's Health Care Ltd..pdf
# 841/3520: Dr. Lal Pathlabs Ltd..pdf
# 842/3520: DRC Systems India Ltd..pdf
# 843/3520: Dreamfolks Services Ltd..pdf
# 844/3520: Dredging Corp Of India Ltd..pdf
# 845/3520: Ducon Infratechnologies Ltd..pdf
# 846/3520: Duke Offshore Ltd..pdf
# 847/3520: Duncan Engineering Ltd..pdf
# 848/3520: Duropack Ltd..pdf
# 849/3520: Duroply Industries Ltd..pdf
# 850/3520: Dutron Polymers Ltd..pdf
# 851/3520: Dwarikesh Sugar Industries Ltd..pdf
# 852/3520: Dynacons Systems & Solutions Ltd..pdf
# 853/3520: Dynamatic Technologies Ltd..pdf
# 854/3520: Dynamic Archistructures Ltd..pdf
# 855/3520: Dynamic Cables Ltd..pdf
# 856/3520: Dynamic Industries Ltd..pdf
# 857/3520: Dynamic Microsteppers Ltd..pdf
# 858/3520: Dynamic Portfolio Management & Services Ltd..pdf
# 859/3520: Dynavision Ltd..pdf
# 860/3520: Dynemic Products Ltd..pdf
# 861/3520: E & E Enterprises Ltd..pdf
# 862/3520: E2E Networks Ltd..pdf
# 863/3520: East Buildtech Ltd..pdf
# 864/3520: East India Drums And Barrels Manufacturing Ltd..pdf
# 865/3520: East West Freight Carriers Ltd..pdf
# 866/3520: Eastern Silk Industries Ltd..pdf
# 867/3520: Easun Capital Markets Ltd..pdf
# 868/3520: Easy Fincorp Ltd..pdf
# 869/3520: Eclerx Services Ltd..pdf
# 870/3520: Eco Hotels And Resorts Ltd..pdf
# 871/3520: Eco Recycling Ltd..pdf
# 872/3520: Ecoboard Industries Ltd..pdf
# 873/3520: Ecofinity Atomix Ltd..pdf
# 874/3520: Econo Trade India Ltd..pdf
# 875/3520: Ecos (India) Mobility and Hospitality Ltd..pdf
# 876/3520: ECS Biztech Ltd..pdf
# 877/3520: Edelweiss Financial Services Ltd..pdf
# 878/3520: Edvenswa Enterprises Ltd..pdf
# 879/3520: EFC (I) Ltd..pdf
# 880/3520: Eicher Motors Ltd..pdf
# 881/3520: EID Parry India Ltd..pdf
# 882/3520: EIH Associated Hotels Ltd..pdf
# 883/3520: EIH Ltd..pdf
# 884/3520: Eiko Lifesciences Ltd..pdf
# 885/3520: Eimco Elecon India Ltd..pdf
# 886/3520: Ekansh Concepts Ltd..pdf
# 887/3520: EL Forge Ltd..pdf
# 888/3520: Elango Industries Ltd..pdf
# 889/3520: Elantas Beck India Ltd..pdf
# 890/3520: ELCID Investments Ltd..pdf
# 891/3520: Eldeco Housing and Industries Ltd..pdf
# 892/3520: Elecon Engineering Company Ltd..pdf
# 893/3520: Electronics Mart India Ltd..pdf
# 894/3520: Electrosteel Castings Ltd..pdf
# 895/3520: Elgi Equipments Ltd..pdf
# 896/3520: Elin Electronics Ltd..pdf
# 897/3520: Elixir Capital Ltd..pdf
# 898/3520: Ellenbarrie Industrial Gases Ltd..pdf
# 899/3520: Elnet Technologies Ltd..pdf
# 900/3520: EMA India Ltd..pdf
# 901/3520: Emami Ltd..pdf
# 902/3520: Emami Paper Mills Ltd..pdf
# 903/3520: Emami Realty Ltd..pdf
# 904/3520: Emcure Pharmaceuticals Ltd..pdf
# 905/3520: Emerald Finance Ltd..pdf
# 906/3520: Emergent Industrial Solutions Ltd..pdf
# 907/3520: Emkay Global Financial Services Ltd..pdf
# 908/3520: Emmessar Biotech & Nutrition Ltd..pdf
# 909/3520: Emmvee Photovoltaic Power Ltd..pdf
# 910/3520: Empire Industries Ltd..pdf
# 911/3520: Empower India Ltd..pdf
# 912/3520: Emrock Corporation Ltd..pdf
# 913/3520: EMS Ltd..pdf
# 914/3520: Emudhra Ltd..pdf
# 915/3520: Encode Packaging India Ltd..pdf
# 916/3520: Endurance Technologies Ltd..pdf
# 917/3520: Engineers India Ltd..pdf
# 918/3520: Enkei Wheels India Ltd..pdf
# 919/3520: Entero Healthcare Solutions Ltd..pdf
# 920/3520: Enterprise International Ltd..pdf
# 921/3520: Entertainment Network India Ltd..pdf
# 922/3520: Envair Electrodyne Ltd..pdf
# 923/3520: Enviro Infra Engineers Ltd..pdf
# 924/3520: Epack Durable Ltd..pdf
# 925/3520: Epack Prefab Technologies Ltd..pdf
# 926/3520: Epic Energy Ltd..pdf
# 927/3520: Epigral Ltd..pdf
# 928/3520: EPL Ltd..pdf
# 929/3520: Epsom Properties Ltd..pdf
# 930/3520: Epuja Spiritech Ltd..pdf
# 931/3520: Equippp Social Impact Technologies Ltd..pdf
# 932/3520: Equitas Small Finance Bank Ltd..pdf
# 933/3520: Eris Lifesciences Ltd..pdf
# 934/3520: Esaar India Ltd..pdf
# 935/3520: Esab India Ltd..pdf
# 936/3520: ESAF Small Finance Bank Ltd..pdf
# 937/3520: Escorp Asset Management Ltd..pdf
# 938/3520: Escorts Kubota Ltd..pdf
# 939/3520: Esha Media Research Ltd..pdf
# 940/3520: Esquire Money Guarantees Ltd..pdf
# 941/3520: Essar Shipping Ltd..pdf
# 942/3520: Ester Industries Ltd..pdf
# 943/3520: Eternal Ltd..pdf
# 944/3520: Ethos Ltd..pdf
# 945/3520: Eureka Forbes Ltd..pdf
# 946/3520: Euro Leder Fashion Ltd..pdf
# 947/3520: Eurotex Industries and Exports Ltd..pdf
# 948/3520: Eveready Industries India Ltd..pdf
# 949/3520: Everest Industries Ltd..pdf
# 950/3520: Everest Kanto Cylinder Ltd..pdf
# 951/3520: Everlon Financials Ltd..pdf
# 952/3520: Evexia Lifecare Ltd..pdf
# 953/3520: Exato Technologies Ltd..pdf
# 954/3520: Excel Industries Ltd..pdf
# 955/3520: Excelsoft Technologies Ltd..pdf
# 956/3520: Exicom Tele-Systems Ltd..pdf
# 957/3520: Exide Industries Ltd..pdf
# 958/3520: Explicit Finance Ltd..pdf
# 959/3520: Expo Engineering and Projects Ltd..pdf
# 960/3520: Exxaro Tiles Ltd..pdf
# 961/3520: Eyantra Ventures Ltd..pdf
# 962/3520: F Mec International Financial Services Ltd..pdf
# 963/3520: Fabtech Technologies Ltd..pdf
# 964/3520: Facor Alloys Ltd..pdf
# 965/3520: Fairchem Organics Ltd..pdf
# 966/3520: Family Care Hospitals Ltd..pdf
# 967/3520: Faze Three Ltd..pdf
# 968/3520: FCS Software Solutions Ltd..pdf
# 969/3520: FDC Ltd..pdf
# 970/3520: Fedbank Financial Services Ltd..pdf
# 971/3520: Federal Bank Ltd..pdf
# 972/3520: Federal-Mogul Goetze (India) Ltd..pdf
# 973/3520: Fermenta Biotech Ltd..pdf
# 974/3520: Fervent Synergies Ltd..pdf
# 975/3520: FGP Ltd..pdf
# 976/3520: Fiem Industries Ltd..pdf
# 977/3520: Filatex India Ltd..pdf
# 978/3520: Filmcity Media Ltd..pdf
# 979/3520: Fine Line Circuits Ltd..pdf
# 980/3520: Fine Organic Industries Ltd..pdf
# 981/3520: Fineotex Chemical Ltd..pdf
# 982/3520: Finkurve Financial Services Ltd..pdf
# 983/3520: Fino Payments Bank Ltd..pdf
# 984/3520: Finolex Cables Ltd..pdf
# 985/3520: Finolex Industries Ltd..pdf
# 986/3520: First Custodian Fund India Ltd..pdf
# 987/3520: Firstsource Solutions Ltd..pdf
# 988/3520: Five-Star Business Finance Ltd..pdf
# 989/3520: Flair Writing Industries Ltd..pdf
# 990/3520: Flex Foods Ltd..pdf
# 991/3520: Flomic Global Logistics Ltd..pdf
# 992/3520: Foods & Inns Ltd..pdf
# 993/3520: Forbes Precision Tools and Machine Parts Ltd..pdf
# 994/3520: Force Motors Ltd..pdf
# 995/3520: Fortis Healthcare Ltd..pdf
# 996/3520: Fortis Malar Hospitals Ltd..pdf
# 997/3520: Foseco Crucible (India) Ltd..pdf
# 998/3520: Foseco India Ltd..pdf
# 999/3520: Foundry Fuel Products Ltd..pdf
# 1000/3520: Fourth Generation Information Systems Ltd..pdf
# 1001/3520: Fractal Analytics Ltd..pdf
# 1002/3520: Franklin Industries Ltd..pdf
# 1003/3520: Fraser And Co Ltd..pdf
# 1004/3520: Fratelli Vineyards Ltd..pdf
# 1005/3520: Fredun Pharmaceuticals Ltd..pdf
# 1006/3520: Frontier Capital Ltd..pdf
# 1007/3520: Frontier Springs Ltd..pdf
# 1008/3520: FSN E-Commerce Ventures Ltd..pdf
# 1009/3520: Fujiyama Power Systems Ltd..pdf
# 1010/3520: Fundviser Capital (India) Ltd..pdf
# 1011/3520: Future Market Networks Ltd..pdf
# 1012/3520: Futuristic Securities Ltd..pdf
# 1013/3520: Futuristic Solutions Ltd..pdf
# 1014/3520: Fynx Capital Ltd..pdf
# 1015/3520: G R Infraprojects Ltd..pdf
# 1016/3520: G-Tech Info-Training Ltd..pdf
# 1017/3520: Gabriel India Ltd..pdf
# 1018/3520: GACM Technologies Ltd. - DVR.pdf
# 1019/3520: GACM Technologies Ltd..pdf
# 1020/3520: Gagan Gases Ltd..pdf
# 1021/3520: GAIL (India) Ltd..pdf
# 1022/3520: Gala Global Products Ltd..pdf
# 1023/3520: Gala Precision Engineering Ltd..pdf
# 1024/3520: Galada Power & Telecommunication Ltd..pdf
# 1025/3520: Galaxy Bearings Ltd..pdf
# 1026/3520: Galaxy Surfactants Ltd..pdf
# 1027/3520: Gallantt Ispat Ltd..pdf
# 1028/3520: Gallops Enterprise Ltd..pdf
# 1029/3520: Gamco Ltd..pdf
# 1030/3520: Gammon India Ltd..pdf
# 1031/3520: Gandhar Oil Refinery India Ltd. .pdf
# 1032/3520: Gandhi Special Tubes Ltd..pdf
# 1033/3520: Ganesh Benzoplast Ltd..pdf
# 1034/3520: Ganesh Consumer Products Ltd..pdf
# 1035/3520: Ganesh Holdings Ltd..pdf
# 1036/3520: Ganesh Housing Ltd..pdf
# 1037/3520: Ganesha Ecosphere Ltd..pdf
# 1038/3520: Ganga Papers India Ltd..pdf
# 1039/3520: Ganges Securities Ltd..pdf
# 1040/3520: Gangotri Textiles Ltd..pdf
# 1041/3520: Ganon Products Ltd..pdf
# 1042/3520: Garden Reach Shipbuilders & Engineers Ltd..pdf
# 1043/3520: Garg Furnace Ltd..pdf
# 1044/3520: Garment Mantra Lifestyle Ltd..pdf
# 1045/3520: Garuda Construction and Engineering Ltd..pdf
# 1046/3520: Garware Hi-Tech Films Ltd..pdf
# 1047/3520: Garware Marine Industries Ltd..pdf
# 1048/3520: Garware Offshore Services Ltd..pdf
# 1049/3520: Garware Synthetics Ltd..pdf
# 1050/3520: Garware Technical Fibres Ltd..pdf
# 1051/3520: Gateway Distriparks Ltd..pdf
# 1052/3520: Gaudium IVF and Women Health Ltd..pdf
# 1053/3520: Gautam Gems Ltd..pdf
# 1054/3520: Gayatri Bioorganics Ltd..pdf
# 1055/3520: Gayatri Highways Ltd..pdf
# 1056/3520: Gayatri Projects Ltd..pdf
# 1057/3520: Gayatri Sugars Ltd..pdf
# 1058/3520: GB Global Ltd..pdf
# 1059/3520: GCM Securities Ltd..pdf
# 1060/3520: GDL Leasing & Finance Ltd..pdf
# 1061/3520: GE Power India Ltd..pdf
# 1062/3520: Ge Vernova T&D India Ltd..pdf
# 1063/3520: Gee Ltd..pdf
# 1064/3520: Geecee Ventures Ltd..pdf
# 1065/3520: Geetanjali Credit And Capital Ltd..pdf
# 1066/3520: Gem Aromatics Ltd..pdf
# 1067/3520: Gemstone Investments Ltd..pdf
# 1068/3520: General Insurance Corporation of India.pdf
# 1069/3520: Genpharmasec Ltd..pdf
# 1070/3520: Genus Paper & Boards Ltd..pdf
# 1071/3520: Genus Power Infrastructures Ltd..pdf
# 1072/3520: Genxai Analytics Ltd..pdf
# 1073/3520: Geojit Financial Services Ltd..pdf
# 1074/3520: GG Automotive Gears Ltd..pdf
# 1075/3520: GG Dandekar Properties Ltd..pdf
# 1076/3520: GG Engineering Ltd..pdf
# 1077/3520: GHCL Ltd..pdf
# 1078/3520: GHCL Textiles Ltd..pdf
# 1079/3520: GHV Infra Projects Ltd..pdf
# 1080/3520: GIC Housing Finance Ltd..pdf
# 1081/3520: Gillanders Arbuthnot & Company Ltd..pdf
# 1082/3520: Gillette India Ltd..pdf
# 1083/3520: Gini Silk Mills Ltd..pdf
# 1084/3520: Ginni Filaments Ltd..pdf
# 1085/3520: Gita Renewable Energy Ltd..pdf
# 1086/3520: GK Consultants Ltd..pdf
# 1087/3520: GK Energy Ltd..pdf
# 1088/3520: GKB Ophthalmics Ltd..pdf
# 1089/3520: GKP Printing & Packaging Ltd..pdf
# 1090/3520: Glance Finance Ltd..pdf
# 1091/3520: Glaxosmithkline Pharmaceuticals Ltd..pdf
# 1092/3520: Glenmark Pharmaceuticals Ltd..pdf
# 1093/3520: Glittek Granites Ltd..pdf
# 1094/3520: Global Capital Markets Ltd..pdf
# 1095/3520: Global Defence Industries Ltd..pdf
# 1096/3520: Global Health Ltd..pdf
# 1097/3520: Global Infratech & Finance Ltd..pdf
# 1098/3520: Global Vectra Helicorp Ltd..pdf
# 1099/3520: Globale Tessile Ltd..pdf
# 1100/3520: Globe Civil Projects Ltd..pdf
# 1101/3520: Globus Constructors & Developers Ltd..pdf
# 1102/3520: Globus Spirits Ltd..pdf
# 1103/3520: Gloster Ltd..pdf
# 1104/3520: GM Breweries Ltd..pdf
# 1105/3520: GMM Pfaudler Ltd..pdf
# 1106/3520: GMR Airports Ltd..pdf
# 1107/3520: GNA Axles Ltd..pdf
# 1108/3520: GNG Electronics Ltd..pdf
# 1109/3520: GO Digit General Insurance Ltd..pdf
# 1110/3520: Go Fashion (India) Ltd..pdf
# 1111/3520: Goa Carbon Ltd..pdf
# 1112/3520: GOCL Corporation Ltd..pdf
# 1113/3520: Godavari Biorefineries Ltd..pdf
# 1114/3520: Godavari Drugs Ltd..pdf
# 1115/3520: Godawari Power And Ispat Ltd..pdf
# 1116/3520: Godfrey Phillips India Ltd..pdf
# 1117/3520: Godrej Agrovet Ltd..pdf
# 1118/3520: Godrej Consumer Products Ltd..pdf
# 1119/3520: Godrej Industries Ltd..pdf
# 1120/3520: Godrej Properties Ltd..pdf
# 1121/3520: Gogia Capital Growth Ltd..pdf
# 1122/3520: Gokak Textiles Ltd..pdf
# 1123/3520: Gokaldas Exports Ltd..pdf
# 1124/3520: Gokul Agro Resources Ltd..pdf
# 1125/3520: Gokul Refoils And Solvent Ltd..pdf
# 1126/3520: Gold Coin Health Foods Ltd..pdf
# 1127/3520: Golden Carpets Ltd..pdf
# 1128/3520: Golden Crest Education & Services Ltd..pdf
# 1129/3520: Golden Legend Leasing & Finance Ltd..pdf
# 1130/3520: Goldiam International Ltd..pdf
# 1131/3520: Golechha Global Finance Ltd..pdf
# 1132/3520: Golkunda Diamonds & Jewellary Ltd..pdf
# 1133/3520: Goodluck India Ltd..pdf
# 1134/3520: Goodricke Group Ltd..pdf
# 1135/3520: Goodyear India Ltd..pdf
# 1136/3520: Gopal Snacks Ltd..pdf
# 1137/3520: Gorani Industries Ltd..pdf
# 1138/3520: Gothi Plascon India Ltd..pdf
# 1139/3520: GP Petroleums Ltd..pdf
# 1140/3520: GPT Healthcare Ltd..pdf
# 1141/3520: GPT Infraprojects Ltd..pdf
# 1142/3520: Grameva Ltd..pdf
# 1143/3520: Grand Foundry Ltd..pdf
# 1144/3520: Grand Oak Canyons Distillery Ltd..pdf
# 1145/3520: Grandma Trading & Agencies Ltd..pdf
# 1146/3520: Granules India Ltd..pdf
# 1147/3520: Graphite India Ltd..pdf
# 1148/3520: Grasim Industries Ltd..pdf
# 1149/3520: Gratex Industries Ltd..pdf
# 1150/3520: Grauer & Weil (India) Ltd..pdf
# 1151/3520: Graviss Hospitality Ltd..pdf
# 1152/3520: Gravita India Ltd..pdf
# 1153/3520: Gravity India Ltd..pdf
# 1154/3520: Great Eastern Shipping Company Ltd..pdf
# 1155/3520: Greaves Cotton Ltd..pdf
# 1156/3520: Greencrest Financial Services Ltd..pdf
# 1157/3520: Greenlam Industries Ltd..pdf
# 1158/3520: Greenpanel Industries Ltd..pdf
# 1159/3520: Greenply Industries Ltd..pdf
# 1160/3520: Gretex Corporate Services Ltd..pdf
# 1161/3520: Grindwell Norton Ltd..pdf
# 1162/3520: GRM Overseas Ltd..pdf
# 1163/3520: Groarc Industries India Ltd..pdf
# 1164/3520: Grovy India Ltd..pdf
# 1165/3520: Growington Ventures India Ltd..pdf
# 1166/3520: GRP Ltd..pdf
# 1167/3520: GS Auto International Ltd..pdf
# 1168/3520: GSB Finance Ltd..pdf
# 1169/3520: GSL Securities Ltd..pdf
# 1170/3520: GSP Crop Science Ltd..pdf
# 1171/3520: GTL Infrastructure Ltd..pdf
# 1172/3520: GTL Ltd..pdf
# 1173/3520: GTN Industries Ltd..pdf
# 1174/3520: GTT Data Solutions Ltd..pdf
# 1175/3520: Gujarat Alkalies and Chemicals Ltd..pdf
# 1176/3520: Gujarat Ambuja Exports Ltd..pdf
# 1177/3520: Gujarat Containers Ltd..pdf
# 1178/3520: Gujarat Cotex Ltd..pdf
# 1179/3520: Gujarat Craft Industries Ltd..pdf
# 1180/3520: Gujarat Energy Ltd..pdf
# 1181/3520: Gujarat Fluorochemicals Ltd..pdf
# 1182/3520: Gujarat Hotels Ltd..pdf
# 1183/3520: Gujarat Industries Power Company Ltd..pdf
# 1184/3520: Gujarat Inject Kerala Ltd..pdf
# 1185/3520: Gujarat Intrux Ltd..pdf
# 1186/3520: Gujarat Investa Ltd..pdf
# 1187/3520: Gujarat Lease Financing Ltd..pdf
# 1188/3520: Gujarat Mineral Development Corp Ltd..pdf
# 1189/3520: Gujarat Narmada Valley Fertilizers & Chemicals Ltd..pdf
# 1190/3520: Gujarat Petrosynthese Ltd..pdf
# 1191/3520: Gujarat Pipavav Port Ltd..pdf
# 1192/3520: Gujarat Poly Electronics Ltd..pdf
# 1193/3520: Gujarat Raffia Industries Ltd..pdf
# 1194/3520: Gujarat State Fertilizers & Chemicals Ltd..pdf
# 1195/3520: Gujarat Terce Laboratories Ltd..pdf
# 1196/3520: Gujarat Themis Biosyn Ltd..pdf
# 1197/3520: Gujarat Winding Systems Ltd..pdf
# 1198/3520: Gujjubhai Industries Ltd..pdf
# 1199/3520: Gulf Oil Lubricants India Ltd..pdf
# 1200/3520: Gulshan Polyols Ltd..pdf
# 1201/3520: Guru Krupa Gems And Jewellery Ltd.pdf
# 1202/3520: Gyan Developers & Builders Ltd..pdf
# 1203/3520: H S India Ltd..pdf
# 1204/3520: Halder Venture Ltd..pdf
# 1205/3520: Haldyn Glass Ltd..pdf
# 1206/3520: Haleos Labs Ltd..pdf
# 1207/3520: Handson Global Management (HGM) Ltd..pdf
# 1208/3520: Happiest Minds Technologies Ltd..pdf
# 1209/3520: Happy Forgings Ltd..pdf
# 1210/3520: Hardcastle & Waud Mfg Co Ltd..pdf
# 1211/3520: Harig Crankshafts Ltd..pdf
# 1212/3520: Hariom Pipe Industries Ltd..pdf
# 1213/3520: Hariyana Ship Breakers Ltd..pdf
# 1214/3520: Hariyana Ventures Ltd..pdf
# 1215/3520: Harmony Capital Services Ltd..pdf
# 1216/3520: Harrisons Malayalam Ltd..pdf
# 1217/3520: Harsha Engineers International Ltd..pdf
# 1218/3520: Haryana Capfin Ltd..pdf
# 1219/3520: Haryana Financial Corp Ltd..pdf
# 1220/3520: Haryana Leather Chemicals Ltd..pdf
# 1221/3520: Hathway Bhawani Cabletel & Datacom Ltd..pdf
# 1222/3520: Hathway Cable & Datacom Ltd..pdf
# 1223/3520: Hatsun Agro Product Ltd..pdf
# 1224/3520: Havells India Ltd..pdf
# 1225/3520: Hawa Engineers Ltd..pdf
# 1226/3520: Hawkins Cookers Ltd..pdf
# 1227/3520: Hazoor Multi Projects Ltd..pdf
# 1228/3520: HB Estate Developers Ltd..pdf
# 1229/3520: HB Leasing & Finance Co Ltd..pdf
# 1230/3520: HB Stockholdings Ltd..pdf
# 1231/3520: HBL Engineering Ltd..pdf
# 1232/3520: HCKK Ventures Ltd..pdf
# 1233/3520: HCL Infosystems Ltd..pdf
# 1234/3520: HCL Technologies Ltd..pdf
# 1235/3520: HCP Plastene Bulkpack Ltd..pdf
# 1236/3520: HDFC Asset Management Company Ltd..pdf
# 1237/3520: HDFC Bank Ltd..pdf
# 1238/3520: HDFC Life Insurance Company Ltd..pdf
# 1239/3520: Health X Platform Ltd..pdf
# 1240/3520: Healthcare Global Enterprises Ltd..pdf
# 1241/3520: Healthy Investments Ltd..pdf
# 1242/3520: Heera Ispat Ltd..pdf
# 1243/3520: HEG Ltd..pdf
# 1244/3520: Heidelbergcement India Ltd..pdf
# 1245/3520: Helpage Finlease Ltd..pdf
# 1246/3520: HEM Holdings & Trading Ltd..pdf
# 1247/3520: Hemadri Cements Ltd..pdf
# ...
# 3109/3520: Tatia Global Vennture Ltd..pdf
# 3110/3520: Tatva Chintan Pharma Chem Ltd..pdf
# 3111/3520: TBO Tek Ltd..pdf
# 3112/3520: TCC Concept Ltd..pdf
# 3113/3520: TCFC Finance Ltd..pdf
# 3114/3520: TCI Express Ltd..pdf
# 3115/3520: TCI Industries Ltd..pdf
# 3116/3520: TCM Ltd..pdf
# 3117/3520: TCPL Packaging Ltd..pdf
# 3118/3520: TD Power Systems Ltd..pdf
# 3119/3520: Team24 Consumer Products Ltd..pdf
# 3120/3520: Teamlease Services Ltd..pdf
# 3121/3520: Teamo Productions HQ Ltd..pdf
# 3122/3520: Tech Mahindra Ltd..pdf
# 3123/3520: Techno Electric & Engineering Company Ltd..pdf
# 3124/3520: Technocraft Industries India Ltd..pdf
# 3125/3520: Technojet Consultants Ltd..pdf
# 3126/3520: Technvision Ventures Ltd..pdf
# 3127/3520: Tecil Chemical and Hydro Power Ltd..pdf
# 3128/3520: Teesta Agro Industries Ltd..pdf
# 3129/3520: Tega Industries Ltd..pdf
# 3130/3520: Tejas Networks Ltd..pdf
# 3131/3520: Tejnaksh Healthcare Ltd..pdf
# 3132/3520: Telge Projects Ltd..pdf
# 3133/3520: Telogica Ltd..pdf
# 3134/3520: Tenneco Clean Air India Ltd..pdf
# 3135/3520: Tera Software Ltd..pdf
# 3136/3520: Terai Tea Co Ltd..pdf
# 3137/3520: Terraform Magnum Ltd..pdf
# 3138/3520: Terraform Realstate Ltd..pdf
# 3139/3520: Texel Industries Ltd..pdf
# 3140/3520: Texmaco Infrastructure & Holdings Ltd..pdf
# 3141/3520: Texmaco Rail & Engineering Ltd..pdf
# 3142/3520: Texmo Pipes And Products Ltd..pdf
# 3143/3520: TGB Banquets And Hotels Ltd..pdf
# 3144/3520: Thacker & Co Ltd..pdf
# 3145/3520: Thakkers Group Ltd..pdf
# 3146/3520: Thangamayil Jewellery Ltd..pdf
# 3147/3520: Themis Medicare Ltd..pdf
# 3148/3520: Thermax Ltd..pdf
# 3149/3520: Thinkink Picturez Ltd..pdf
# 3150/3520: Thirumalai Chemicals Ltd..pdf
# 3151/3520: Thomas Cook (India)  Ltd..pdf
# 3152/3520: Thrive Future Habitats Ltd..pdf
# 3153/3520: Thyrocare Technologies Ltd..pdf
# 3154/3520: Tiaan Consumer Ltd..pdf
# 3155/3520: Tiger Logistics (India) Ltd..pdf
# 3156/3520: TIL Ltd..pdf
# 3157/3520: Tilak Ventures Ltd..pdf
# 3158/3520: Tilaknagar Industries Ltd..pdf
# 3159/3520: Time Technoplast Ltd..pdf
# 3160/3520: Timex Group India Ltd..pdf
# 3161/3520: Timken India Ltd..pdf
# 3162/3520: Tinna Rubber And Infrastructure Ltd..pdf
# 3163/3520: Tips Music Ltd..pdf
# 3164/3520: Tirth Plastic Ltd..pdf
# 3165/3520: Tirupati Fincorp Ltd..pdf
# 3166/3520: Tirupati Finlease Ltd..pdf
# 3167/3520: Tirupati Foam Ltd..pdf
# 3168/3520: Tirupati Sarjan Ltd..pdf
# 3169/3520: Titagarh Rail Systems Ltd..pdf
# 3170/3520: Titan Biotech Ltd..pdf
# 3171/3520: Titan Company Ltd..pdf
# 3172/3520: Titan Intech Ltd..pdf
# 3173/3520: Titan Securities Ltd..pdf
# 3174/3520: Tokyo Finance Ltd..pdf
# 3175/3520: Tokyo Plast International Ltd..pdf
# 3176/3520: Tolins Tyres Ltd..pdf
# 3177/3520: Tomorrow Technologies Global Innovations Ltd..pdf
# 3178/3520: Torrent Pharmaceuticals Ltd..pdf
# 3179/3520: Torrent Power Ltd..pdf
# 3180/3520: Tourism Finance Corp Of India Ltd..pdf
# 3181/3520: Toyam Sports Ltd..pdf
# 3182/3520: TPL Plastech Ltd..pdf
# 3183/3520: Tracxn Technologies Ltd..pdf
# 3184/3520: Trade Wings Ltd..pdf
# 3185/3520: Trans Freight Containers Ltd..pdf
# 3186/3520: Trans India House Impex Ltd..pdf
# 3187/3520: Transcorp International Ltd..pdf
# 3188/3520: Transformers and Rectifiers (India) Ltd..pdf
# 3189/3520: Transgene Biotek Ltd..pdf
# 3190/3520: Transglobe Foods Ltd..pdf
# 3191/3520: Transindia Real Estate Ltd..pdf
# 3192/3520: Transoceanic Properties Ltd..pdf
# 3193/3520: Transpek Industry Ltd..pdf
# 3194/3520: Transport Corporation Of India Ltd..pdf
# 3195/3520: Transrail Lighting Ltd..pdf
# 3196/3520: Transwarranty Finance Ltd..pdf
# 3197/3520: Transworld Shipping Lines Ltd..pdf
# 3198/3520: Travel Food Services Ltd..pdf
# 3199/3520: Tree House Education & Accessories Ltd..pdf
# 3200/3520: Trejhara Solutions Ltd..pdf
# 3201/3520: Trent Ltd..pdf
# 3202/3520: Trescon Ltd..pdf
# 3203/3520: TRF Ltd..pdf
# 3204/3520: Tribhovandas Bhimji Zaveri Ltd..pdf
# 3205/3520: Trident Lifeline Ltd..pdf
# 3206/3520: Trident Ltd..pdf
# 3207/3520: Trident Texofab Ltd..pdf
# 3208/3520: Trigyn Technologies Ltd..pdf
# 3209/3520: Triliance Polymers Ltd..pdf
# 3210/3520: Trinity League India Ltd..pdf
# 3211/3520: Trinity Tradelink Ltd..pdf
# 3212/3520: Trio Mercantile & Trading Ltd..pdf
# 3213/3520: Trishakti Industries Ltd..pdf
# 3214/3520: Triton Valves Ltd..pdf
# 3215/3520: Triveni Engineering & Industries Ltd..pdf
# 3216/3520: Triveni Enterprises Ltd..pdf
# 3217/3520: Triveni Glass Ltd..pdf
# 3218/3520: Trualt Bioenergy Ltd..pdf
# 3219/3520: Trucap Finance Ltd..pdf
# 3220/3520: True Green Bio Energy Ltd..pdf
# 3221/3520: Trustedge Capital Ltd..pdf
# 3222/3520: TT Ltd..pdf
# 3223/3520: TTI Enterprise Ltd..pdf
# 3224/3520: TTK Healthcare Ltd..pdf
# 3225/3520: TTK Prestige Ltd..pdf
# 3226/3520: TTL Enterprises Ltd..pdf
# 3227/3520: Tulasee Bio-Ethanol Ltd..pdf
# 3228/3520: Tulsi Extrusions Ltd..pdf
# 3229/3520: Tulsyan Nec Ltd..pdf
# 3230/3520: Tuni Textile Mills Ltd..pdf
# 3231/3520: Turner Industries Ltd..pdf
# 3232/3520: Turtlemint Fintech Solutions Ltd..pdf
# 3233/3520: Tusaldah Ltd..pdf
# 3234/3520: Tuticorin Alkali Chemicals And Fertilizers Ltd..pdf
# 3235/3520: TV Today Network Ltd..pdf
# 3236/3520: TVS Electronics Ltd..pdf
# 3237/3520: TVS Holdings Ltd..pdf
# 3238/3520: TVS Motor Company Ltd..pdf
# 3239/3520: TVS Srichakra Ltd..pdf
# 3240/3520: Twamev Construction And Infrastructure Ltd..pdf
# 3241/3520: Twentyfirst Century Management Services Ltd..pdf
# 3242/3520: Twin Roses Trades & Agencies Ltd..pdf
# 3243/3520: Tyche Industries Ltd..pdf
# 3244/3520: Typhoon Financial Services Ltd..pdf
# 3245/3520: Tyroon Tea Co Ltd..pdf
# 3246/3520: U. Y. Fincorp Ltd..pdf
# 3247/3520: U.H. Zaveri Ltd..pdf
# 3248/3520: Ucal Ltd..pdf
# 3249/3520: UCO Bank.pdf
# 3250/3520: Uday Jewellery Industries Ltd..pdf
# 3251/3520: UFM Industries Ltd..pdf
# 3252/3520: UFO Moviez India Ltd..pdf
# 3253/3520: Ugar Sugar Works Ltd..pdf
# 3254/3520: Ugro Capital Ltd..pdf
# 3255/3520: UHM Vacation Ltd..pdf
# 3256/3520: Ujaas Energy Ltd..pdf
# 3257/3520: Ujjivan Small Finance Bank Ltd..pdf
# 3258/3520: Ultracab (India) Ltd..pdf
# 3259/3520: Ultramarine & Pigments Ltd..pdf
# 3260/3520: Ultratech Cement Ltd..pdf
# 3261/3520: Umiya Buildcon Ltd..pdf
# 3262/3520: UNi Abex Alloy Products Ltd..pdf
# 3263/3520: Unichem Laboratories Ltd..pdf
# 3264/3520: Unick Fix-A-Form And Printers Ltd..pdf
# 3265/3520: Unicommerce Esolutions Ltd..pdf
# 3266/3520: Unifinz Capital India Ltd..pdf
# 3267/3520: Unijolly Investments Co Ltd..pdf
# 3268/3520: Unimech Aerospace and Manufacturing Ltd..pdf
# 3269/3520: Union Bank Of India.pdf
# 3270/3520: Uniparts India Ltd..pdf
# 3271/3520: Uniphos Enterprises Ltd..pdf
# 3272/3520: Unipro Technologies Ltd..pdf
# 3273/3520: Unique Organics Ltd..pdf
# 3274/3520: Uniroyal Industries Ltd..pdf
# 3275/3520: Uniroyal Marine Exports Ltd..pdf
# 3276/3520: Unitech Ltd..pdf
# 3277/3520: United Breweries Ltd..pdf
# 3278/3520: United Credit Ltd..pdf
# 3279/3520: United Foodbrands Ltd..pdf
# 3280/3520: United Interactive Ltd..pdf
# 3281/3520: United Spirits Ltd..pdf
# 3282/3520: United Textiles Ltd..pdf
# 3283/3520: United Van Der Horst Ltd..pdf
# 3284/3520: Univa Foods Ltd..pdf
# 3285/3520: Universal Arts Ltd..pdf
# 3286/3520: Universal Autofoundry Ltd..pdf
# 3287/3520: Universal Cables Ltd..pdf
# 3288/3520: Universal Office Automation Ltd..pdf
# 3289/3520: Universal Starch Chem Allied Ltd..pdf
# 3290/3520: Universus Photo Imagings Ltd..pdf
# 3291/3520: Uniworth Securities Ltd..pdf
# 3292/3520: Unjha Formulations Ltd..pdf
# 3293/3520: UNO Minda Ltd..pdf
# 3294/3520: UP Hotels Ltd..pdf
# 3295/3520: Updater Services Ltd..pdf
# 3296/3520: UPL Ltd..pdf
# 3297/3520: Upsurge Investment & Finance Ltd..pdf
# 3298/3520: UR Sugar Industries Ltd..pdf
# 3299/3520: Uravi Defence And Technology Ltd..pdf
# 3300/3520: Urban Company Ltd..pdf
# 3301/3520: Urja Global Ltd..pdf
# 3302/3520: USG Tech Solutions Ltd..pdf
# 3303/3520: Usha Martin Education & Solutions Ltd..pdf
# 3304/3520: Usha Martin Ltd..pdf
# 3305/3520: Ushakiran Finance Ltd..pdf
# 3306/3520: UTI Asset Management Company Ltd..pdf
# 3307/3520: Utkarsh Small Finance Bank Ltd..pdf
# 3308/3520: UTL Industries Ltd..pdf
# 3309/3520: V R Films & Studios Ltd..pdf
# 3310/3520: V-Guard Industries Ltd..pdf
# 3311/3520: V-Mart Retail Ltd..pdf
# 3312/3520: V2 Retail Ltd..pdf
# 3313/3520: VA Tech Wabag Ltd..pdf
# 3314/3520: Vadilal Dairy International Ltd..pdf
# 3315/3520: Vadilal Enterprises Ltd..pdf
# 3316/3520: Vadilal Industries Ltd..pdf
# 3317/3520: Vaibhav Global Ltd..pdf
# 3318/3520: Vaishno Cement Company Ltd..pdf
# 3319/3520: Vakrangee Ltd..pdf
# 3320/3520: Valecha Engineering Ltd..pdf
# 3321/3520: Valiant Communications Ltd..pdf
# 3322/3520: Valiant Laboratories Ltd..pdf
# 3323/3520: Valiant Organics Ltd..pdf
# 3324/3520: Vallabh Steels Ltd..pdf
# 3325/3520: Valley Magnesite Co Ltd..pdf
# 3326/3520: Vani Commercials Ltd..pdf
# 3327/3520: Vantage Knowledge Academy Ltd..pdf
# 3328/3520: Vapi Enterprise Ltd..pdf
# 3329/3520: Vardhan Capital & Finance Ltd..pdf
# 3330/3520: Vardhman Holdings Ltd..pdf
# 3331/3520: Vardhman Special Steels Ltd..pdf
# 3332/3520: Vardhman Textiles Ltd..pdf
# 3333/3520: Variman Global Enterprises Ltd..pdf
# 3334/3520: Varroc Engineering Ltd..pdf
# 3335/3520: Varun Beverages Ltd..pdf
# 3336/3520: Varun Mercantile Ltd..pdf
# 3337/3520: Varvee Global Ltd..pdf
# 3338/3520: Vas Infrastructure Ltd..pdf
# 3339/3520: Vascon Engineers Ltd..pdf
# 3340/3520: Vashu Bhagnani Industries Ltd..pdf
# 3341/3520: VB Desai Financial Services Ltd..pdf
# 3342/3520: VB Industries Ltd..pdf
# 3343/3520: Vedant Fashions Ltd..pdf
# 3344/3520: Vedanta Aluminium Metal Ltd..pdf
# 3345/3520: Vedanta Iron and Steel Ltd..pdf
# 3346/3520: Vedanta Ltd..pdf
# 3347/3520: Vedanta Oil and Gas Ltd..pdf
# 3348/3520: Vedanta Power Ltd..pdf
# 3349/3520: Veedol Corporation Ltd..pdf
# 3350/3520: Veefin Solutions Ltd..pdf
# 3351/3520: Veejay Lakshmi Engineering Works Ltd..pdf
# 3352/3520: Veer Energy & Infrastructure Ltd..pdf
# 3353/3520: Veer Global Infraconstruction Ltd..pdf
# 3354/3520: Veerhealth Care Ltd..pdf
# 3355/3520: Vega Jewellers Ltd..pdf
# 3356/3520: Velan Hotels Ltd..pdf
# 3357/3520: Veljan Denison Ltd..pdf
# 3358/3520: Vellora Impact Ltd.pdf
# 3359/3520: Venkys India Ltd..pdf
# 3360/3520: Venmax Drugs And Pharmaceuticals Ltd..pdf
# 3361/3520: Ventive Hospitality Ltd..pdf
# 3362/3520: Ventura Guaranty Ltd..pdf
# 3363/3520: Venus Pipes & Tubes Ltd..pdf
# 3364/3520: Venus Remedies Ltd..pdf
# 3365/3520: Veranda Learning Solutions Ltd..pdf
# 3366/3520: Veritas India Ltd..pdf
# 3367/3520: Veronica Production Ltd..pdf
# 3368/3520: Vertex Securities Ltd..pdf
# 3369/3520: Vesuvius India Ltd..pdf
# 3370/3520: Veto Switchgears And Cables Ltd..pdf
# 3371/3520: Viaan Industries Ltd..pdf
# 3372/3520: Vibhor Steel Tubes Ltd..pdf
# 3373/3520: Viceroy Hotels Ltd..pdf
# 3374/3520: Victoria Enterprises Ltd..pdf
# 3375/3520: Victoria Mills Ltd..pdf
# 3376/3520: Vidhi Specialty Food Ingredients Ltd..pdf
# 3377/3520: Vidya Wires Ltd..pdf
# 3378/3520: Vijaya Diagnostic Centre Ltd..pdf
# 3379/3520: Viji Finance Ltd..pdf
# 3380/3520: Vikas Ecotech Ltd..pdf
# 3381/3520: Vikram Aroma Ltd..pdf
# 3382/3520: Vikram Kamats Hospitality Ltd..pdf
# 3383/3520: Vikram Solar Ltd..pdf
# 3384/3520: Vikram Thermo India Ltd..pdf
# 3385/3520: Vikran Engineering Ltd..pdf
# 3386/3520: Viksit Engineering Ltd..pdf
# 3387/3520: Vimta Labs Ltd..pdf
# 3388/3520: Vinati Organics Ltd..pdf
# 3389/3520: Vinayak Polycon International Ltd..pdf
# 3390/3520: Vinayak Vanijya Ltd..pdf
# 3391/3520: Vindhya Telelinks Ltd..pdf
# 3392/3520: Vintage Coffee And Beverages Ltd..pdf
# 3393/3520: Vinyl Chemicals India Ltd..pdf
# 3394/3520: Vinyoflex Ltd..pdf
# 3395/3520: VIP Clothing Ltd..pdf
# 3396/3520: VIP Industries Ltd..pdf
# 3397/3520: Viram Suvarn Ltd..pdf
# 3398/3520: Virat Crane Industries Ltd..pdf
# 3399/3520: Virat Industries Ltd..pdf
# 3400/3520: Virat Leasing Ltd..pdf
# 3401/3520: Virgo Polymers India Ltd..pdf
# 3402/3520: Virinchi Ltd..pdf
# 3403/3520: Virtual Global Education Ltd..pdf
# 3404/3520: Virtuoso Optoelectronics Ltd..pdf
# 3405/3520: Virya Resources Ltd..pdf
# 3406/3520: VISA Chrome Ltd..pdf
# 3407/3520: Visagar Polytex Ltd..pdf
# 3408/3520: Visaka Industries Ltd..pdf
# 3409/3520: Vishal Bearings Ltd..pdf
# 3410/3520: Vishal Fabrics Ltd..pdf
# 3411/3520: Vishal Mega Mart Ltd..pdf
# 3412/3520: Vishnu Chemicals Ltd..pdf
# 3413/3520: Vishnu Prakash R Punglia Ltd..pdf
# 3414/3520: Vishwaraj Sugar Industries Ltd..pdf
# 3415/3520: Vision Cinemas Ltd..pdf
# 3416/3520: Vistar Amar Ltd..pdf
# 3417/3520: Vivanta Industries Ltd..pdf
# 3418/3520: Vivanza Biosciences Ltd..pdf
# 3419/3520: Vivid Global Industries Ltd..pdf
# 3420/3520: Vivid Mercantile Ltd..pdf
# 3421/3520: Vivimed Labs Ltd..pdf
# 3422/3520: Vivo Bio Tech Ltd..pdf
# 3423/3520: Viyash Scientific Ltd..pdf
# 3424/3520: VK Global Industries Ltd..pdf
# 3425/3520: VLS Finance Ltd..pdf
# 3426/3520: VMS Industries Ltd..pdf
# 3427/3520: VMS TMT Ltd..pdf
# 3428/3520: Vodafone Idea Ltd..pdf
# 3429/3520: Voith Paper Fabrics India Ltd..pdf
# 3430/3520: Voltaire Leasing & Finance Ltd..pdf
# 3431/3520: Voltamp Transformers Ltd..pdf
# 3432/3520: Vraj Iron And Steel Ltd..pdf
# 3433/3520: VRL Logistics Ltd..pdf
# 3434/3520: VST Industries Ltd..pdf
# 3435/3520: VST Tillers Tractors Ltd..pdf
# 3436/3520: VTM Ltd..pdf
# 3437/3520: VXL Instruments Ltd..pdf
# 3438/3520: Waaree Energies Ltd..pdf
# 3439/3520: Waaree Renewable Technologies Ltd..pdf
# 3440/3520: Wakefit Innovations Ltd..pdf
# 3441/3520: Walchand Peoplefirst Ltd..pdf
# 3442/3520: Walchandnagar Industries Ltd..pdf
# 3443/3520: Wallfort Financial Services Ltd..pdf
# 3444/3520: Wanbury Ltd..pdf
# 3445/3520: Wardwizard Healthcare Ltd..pdf
# 3446/3520: Waterbase Ltd..pdf
# 3447/3520: Waterways Leisure Tourism Ltd..pdf
# 3448/3520: WE Win Ltd..pdf
# 3449/3520: Wealth First Portfolio Managers Ltd..pdf
# 3450/3520: Weizmann Ltd..pdf
# 3451/3520: Welcast Steels Ltd..pdf
# 3452/3520: Welspun Corp Ltd..pdf
# 3453/3520: Welspun Enterprises Ltd..pdf
# 3454/3520: Welspun Investments And Commercials Ltd..pdf
# 3455/3520: Welspun Living Ltd..pdf
# 3456/3520: Welspun Specialty Solutions Ltd..pdf
# 3457/3520: Wendt India Ltd..pdf
# 3458/3520: WEP Solutions Ltd..pdf
# 3459/3520: West Coast Paper Mills Ltd..pdf
# 3460/3520: West Leisure Resorts Ltd..pdf
# 3461/3520: Western Ministil Ltd..pdf
# 3462/3520: Westlife Foodworld Ltd..pdf
# 3463/3520: WeWork India Management Ltd..pdf
# 3464/3520: WH Brady & Co Ltd..pdf
# 3465/3520: Wheels India Ltd..pdf
# 3466/3520: Whirlpool Of India Ltd..pdf
# 3467/3520: Williamson Financial Services Ltd..pdf
# 3468/3520: Williamson Magor & Company Ltd..pdf
# 3469/3520: Windlas Biotech Ltd..pdf
# 3470/3520: Windsor Machines Ltd..pdf
# 3471/3520: Winro Commercial India Ltd..pdf
# 3472/3520: Winsome Textile Industries Ltd..pdf
# 3473/3520: Wipro Ltd..pdf
# 3474/3520: Wires & Fabriks (SA) Ltd..pdf
# 3475/3520: Wisec Global Ltd..pdf
# 3476/3520: Wockhardt Ltd..pdf
# 3477/3520: Wonder Electricals Ltd..pdf
# 3478/3520: Wonderla Holidays Ltd..pdf
# 3479/3520: Woodsvilla Ltd..pdf
# 3480/3520: Worldwide Aluminium Ltd..pdf
# 3481/3520: Worth Investment & Trading Co Ltd..pdf
# 3482/3520: Worth Peripherals Ltd..pdf
# 3483/3520: WPIL Ltd..pdf
# 3484/3520: WSFX Global Pay Ltd..pdf
# 3485/3520: Xchanging Solutions Ltd..pdf
# 3486/3520: XL Energy Ltd..pdf
# 3487/3520: Xpro India Ltd..pdf
# 3488/3520: Xtglobal Infotech Ltd..pdf
# 3489/3520: Yaan Enterprises Ltd..pdf
# 3490/3520: Yamini Investments Co Ltd..pdf
# 3491/3520: Yamuna Syndicate Ltd..pdf
# 3492/3520: Yarn Syndicate Ltd..pdf
# 3493/3520: Yash Innoventures Ltd..pdf
# 3494/3520: Yash Management & Satellite Ltd..pdf
# 3495/3520: Yasho Industries Ltd..pdf
# 3496/3520: Yatra Online Ltd..pdf
# 3497/3520: YES Bank Ltd..pdf
# 3498/3520: Yogi Ltd..pdf
# 3499/3520: Yogi Sungwon India Ltd..pdf
# 3500/3520: Yuken India Ltd..pdf
# 3501/3520: Yunik Managing Advisors Ltd..pdf
# 3502/3520: Yuranus Infrastructure Ltd..pdf
# 3503/3520: Yuvraaj Hygiene Products Ltd..pdf
# 3504/3520: Zee Learn Ltd..pdf
# 3505/3520: Zen Technologies Ltd..pdf
# 3506/3520: Zenith Exports Ltd..pdf
# 3507/3520: Zenith Steel Pipes & Industries Ltd..pdf
# 3508/3520: Zenlabs Ethica Ltd..pdf
# 3509/3520: Zenotech Laboratories Ltd..pdf
# 3510/3520: Zensar Technologies Ltd..pdf
# 3511/3520: ZF Commercial Vehicle Control Systems India Ltd..pdf
# 3512/3520: ZF Steering Gear India Ltd..pdf
# 3513/3520: Zim Laboratories Ltd..pdf
# 3514/3520: Zodiac Clothing Company Ltd..pdf
# 3515/3520: Zodiac Energy Ltd..pdf
# 3516/3520: Zodiac-JRD MKJ Ltd..pdf
# 3517/3520: Zuari Agro Chemicals Ltd..pdf
# 3518/3520: Zuari Industries Ltd..pdf
# 3519/3520: Zydus Lifesciences Ltd..pdf
# 3520/3520: Zydus Wellness Ltd..pdf

# %%
df = pd.DataFrame(probe_data)

df["max_x_hits"] = df["probe_x_hits"].apply(lambda x: max(x) if x else 0)
df["total_x_hits"] = df["probe_x_hits"].apply(lambda x: sum(x) if x else 0)
df["x_hits>1"] = df["probe_x_hits"].apply(lambda x: sum(i > 1 for i in x) if x else 0)
df["x_cons_hit"] = df["probe_x_hits"].apply(lambda x: consecutive_hits(x, threshold=1) if x else 0)

mask = df["page_type"].eq("text")
df.loc[mask, "numeric_score"] = (df[mask].groupby("pdf")["numeric_count"].rank(pct=True).round(1))
df.loc[mask, "hits_score"] = (df[mask].groupby("pdf")["total_x_hits"].rank(pct=True).round(1))
df.loc[mask, "cons_score"] = (df[mask].groupby("pdf")["x_cons_hit"].rank(pct=True).round(1))
df.loc[mask, "line_score"] = (df[mask].groupby("pdf")["line_count"].rank(pct=True).round(1))

df.loc[mask, "structural_score"] = (
    0.60 * df.loc[mask, "numeric_score"]
    + 0.30 * df.loc[mask, "hits_score"]
    + 0.10 * df.loc[mask, "cons_score"]
).round(1)
score_cols = [
    "numeric_score",
    "hits_score",
    "cons_score",
    "line_score",
    "structural_score",
]

df[score_cols] = df[score_cols].fillna(0)
df = add_sequential_features(df)

ndf = df.drop(
    columns=[
        "spread",
        "split_x",
        "probe_x",
        "probe_y",
        "probe_x_hits",
        "probe_y_hits",
        "numeric_lines",
        "headline_data",
    ],
    errors="ignore",
)

excel_path = f"{Path(folder_path).stem}_ANALYSIS.xlsx"

with pd.ExcelWriter(excel_path, engine="openpyxl") as writer:
    ndf.to_excel(writer, sheet_name="page_wise", index=False)
    pd.DataFrame(pdf_data).to_excel(writer, sheet_name="pdf_wise", index=False)

print(f"Saved: {excel_path}")
# Out:
# Saved: Quarterly Results 2026 Q1_ANALYSIS.xlsx

# %% [markdown]
# LEGACY PDF PIPELINE

# %%
folder_path = r"C:\Users\kaustubh.keny\Documents\Quarterly Results 2026 Q1"

probe_data = []
pdf_data = []

files = os.listdir(folder_path)
total_files = len(files)



for idx, file in enumerate(files):
    print(f"{idx}/{total_files}: {file}")
    pdf_path = os.path.join(folder_path, file)
    pdf_file = Path(pdf_path)

    start_t = time.perf_counter()

    with fitz.open(pdf_path) as doc:

        total_pages = doc.page_count

        # Reference dimensions for spread detection
        ref_page = doc[0]
        rw = ref_page.rect.width
        rh = ref_page.rect.height

        for page_no, page in enumerate(doc):

            layout = page_layout_metadata(page, rw, rh)

            w = layout["width"]
            h = layout["height"]

            page_number = page_no + 1

            if layout["spread"]:

                split_x = layout["split_x"]

                regions = (
                    (
                        {"x0": 0, "y0": 0, "x1": split_x, "y1": h},
                        "L",
                    ),
                    (
                        {"x0": split_x, "y0": 0, "x1": w, "y1": h},
                        "R",
                    ),
                )

            else:

                regions = (
                    (
                        {"x0": 0, "y0": 0, "x1": w, "y1": h},
                        "S",
                    ),
                )

            for region, side in regions:

                metadata = {
                    "pdf": pdf_file.stem,
                    "page_n": page_number,
                    "side": side,
                }

                metadata.update(
                    page_content_metadata_v1(
                        page,
                        layout,
                        region,
                    )
                )

                metadata = page_probe_metadata_v1(metadata)

                probe_data.append(metadata)

    elapsed = time.perf_counter() - start_t

    pdf_data.append(
        {
            "pdf_name": pdf_file.stem,
            "total_pages": total_pages,
            "file_size": os.path.getsize(pdf_path),
            "time_elapsed": elapsed,
        }
    )

# %%
df = pd.DataFrame(probe_data)
#X
df["max_x_hits"] = df["probe_x_hits"].apply(lambda x: max(x) if x else 0)
df["total_x_hits"] = df["probe_x_hits"].apply(lambda x: sum(x) if x else 0)
df["x_hits>1"] = df["probe_x_hits"].apply(lambda x : sum(i> 1 for i in x) if x else 0)
df["x_cons_hit"] = df["probe_x_hits"].apply(lambda x: consecutive_hits(x, threshold=1) if x else 0)
#Y
# df["max_y_hits"] = df["probe_y_hits"].apply(lambda x: max(x) if x else 0)
# df["total_y_hits"] = df["probe_y_hits"].apply(lambda x: sum(x) if x else 0)
# df["y_hits>1"] = df["probe_y_hits"].apply(lambda x : sum(i> 1 for i in x) if x else 0)
# df["y_cons_hit"] = df["probe_y_hits"].apply(lambda x: consecutive_hits(x, threshold=1) if x else 0)

# df["numeric_score"] = df.groupby("pdf")["numeric_count"].rank(pct=True).round(1)
# df["hits_score"] = df.groupby("pdf")["total_x_hits"].rank(pct=True).round(1)
# df["cons_score"] = df.groupby("pdf")["x_cons_hit"].rank(pct=True).round(1)
# df["line_score"] = df.groupby("pdf")["line_count"].rank(pct=True).round(1)
# df["structural_score"] = (
#     0.60 * df["numeric_score"]
#     + 0.30 * df["hits_score"]
#     + 0.10 * df["cons_score"]
#     # + 0.20 * df["line_score"]
# ).round(1)

# df = add_sequential_features(df)
ndf = df.drop(["spread","split_x","probe_x","probe_y","probe_x_hits","probe_y_hits","numeric_lines","headline_data"],axis = 1)

fp = Path(folder_path)
excel_path = f"{fp.stem}_HITS.xlsx"
df1 = pd.DataFrame(pdf_data)
with pd.ExcelWriter(excel_path, engine="openpyxl") as writer:
    ndf.to_excel(writer, sheet_name ="page_wise" ,index=False)
    df1.to_excel(writer,sheet_name ="pdf_wise",index=False)
