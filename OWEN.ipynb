# %%
import requests

url = "http://172.22.225.147:8010/v1/chat/completions"

headers = {
    "Authorization": "dummy",
    "Content-Type": "application/json"
}

payload = {
    "model": "Qwen/Qwen3-Coder-30B-A3B-Instruct",
    "messages": [
        {
            "role": "user",
            "content": "How Many Runs has Rohit Sharma scored in IPL"
        }
    ],
    "temperature": 0.7
}

response = requests.post(url, headers=headers, json=payload)

print(response.json())
